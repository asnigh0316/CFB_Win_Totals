# %% [markdown]
# # College Football Win Total Cleaning from Web Scraping

# %% [markdown]
# The purpose of this project is to convert the Vegas win totals for the upcoming College Football 2023 into an easy to read hiearachy by converting the vig for the over number and recombining that with the original win total. We will scrape this data from DraftKings and then clean it prior to processing in a pandas DataFrame. This project also has a Quality Assurance section at the end for those that are interested.

# %%
# Use BeautifulSoup to get the Win Total data

import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

url = 'https://dknation.draftkings.com/2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule'
page = requests.get(url)
  
soup = BeautifulSoup(page.text, 'html.parser')
# Out:
# /Users/alecnigh/opt/anaconda3/lib/python3.8/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (2.0.3) or chardet (3.0.4)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
# Let's look at our soup

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>College football win totals 2023: Over under wins for every team in FBS; Georgia, Alabama, USC, more - DraftKings Network</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="DraftKings Network" name="apple-mobile-web-app-title">
# <meta content="Collin Sherwin" property="author">
# <meta content="2023-05-16T10:44:07-07:00" property="article:published_time">
# <meta content="2023-05-16T11:06:25-07:00" property="article:modified_time"/>
# <link href="https://use.typekit.net" rel="preconnect"/>
# <meta data-cdata='{"version":"c21d9ae195b0d525cd96fab205882683","fonts_catalog":[],"font_stylesheets":["https://fonts.googleapis.com/css2?family=Montserrat:ital,wght@0,400;0,600;0,700;0,900;1,400&amp;display=swap"],"font_tracker_stylesheets":[],"typekit_ids":[],"headline_balance_div_classes":"","headline_balance_fraction":1.0}' data-cid="site/font_loader-1687970634_1558_31303" id="chorus-fonts"/>
# <script>var chorusInitQueue=[],volume_embed_host="https://volume.vox-cdn.com";var Chorus=Chorus||{};Chorus.windowLoaded=!1,Chorus.AddScript=function(t,e){var o=document.createElement("script");o.async=!0,o.type="text/javascript",o.src=t,"function"==typeof e&&(o.onload=e);var a=document.getElementsByTagName("script")[0];return a.parentNode.insertBefore(o,a),o},Chorus.ready=function(t){"loading"!=document.readyState?t():document.addEventListener?document.addEventListener("DOMContentLoaded",t):document.attachEvent("onreadystatechange",function(){"loading"!=document.readyState&&t()})},Chorus.OnLoad=function(t){if(Chorus.windowLoaded=!0)return void t();var e=window.onload;"function"!=typeof window.onload?window.onload=t:window.onload=function(){e(),t()}},Chorus.OnLoad(function(){Chorus.windowLoaded=!0});var dataLayer=dataLayer||[];Chorus.OnLoad(function(){var t;void 0!==navigator.doNotTrack?t=navigator.doNotTrack:void 0!==window.doNotTrack?t=window.doNotTrack:void 0!==navigator.msDoNotTrack&&(t=navigator.msDoNotTrack),t=void 0!==t?/1|yes|true/.test(String(t).toLowerCase())?"true":"false":"undefined";var e={DNT:t};dataLayer.push(e)});var VoxMediaFontLoader=function(t){function e(t,e){var o=window.performance;if(o&&o.mark&&o.measure){var a=t.toLocaleLowerCase().replace(/\W+/g,"_")+(e?"_"+e:"");o.mark(a),o.measure(a+"_time","navigationStart",a)}}function o(){s.classList.add(c),e("fonts_success")}function a(){s.classList.add(c),e("fonts_fail")}function n(t){var o=[t.family,t.style,t.weight,"loaded"].join(" ");e(o)}function r(t){var e=u.font_stylesheets||[];t&&(e=e.filter(function(e){return!e.match(t)})),e.forEach(i)}function i(e){var o=t.createElement("link");o.href=e,o.rel="stylesheet",o.media="all",f.parentNode.insertBefore(o,f)}function d(e){var o,a=t,n=a.documentElement,r=setTimeout(function(){n.className=n.className.replace(/\bwf-loading\b/g,"")+" wf-inactive"},e.scriptTimeout),i=a.createElement("script"),d=!1,c=a.getElementsByTagName("script")[0];n.className+=" wf-loading",i.src="https://use.typekit.net/"+e.kitId+".js",i.async=!0,i.onload=i.onreadystatechange=function(){if(o=this.readyState,!(d||o&&"complete"!=o&&"loaded"!=o)){d=!0,clearTimeout(r);try{Typekit.load(e)}catch(t){}}},c.parentNode.insertBefore(i,c)}var c="fonts-loaded",s=t.documentElement,f=t.getElementById("chorus-fonts");if(f){var u=JSON.parse(f.getAttribute("data-cdata"));if(t.fonts){r("voxmedia.com");var l=[];u.fonts_catalog.forEach(function(e){if(e.woff2_url||e.woff_url){var o=[e.woff2_url,e.woff_url].filter(function(t){return t}).map(function(t){return"url("+t+")"}).join(", "),a=new FontFace(e.family,o,{weight:e.weight,style:e.style,display:"swap"});t.fonts.add(a),l.push(a.load())}}),l.length>0?Promise.allSettled(l).then(function(t){o(),t.filter(function(t){return"fulfilled"===t.status}).forEach(function(t){n(t.value)})})["catch"](function(){a()}):t.fonts.ready.then(o,a)}else r();u.typekit_ids.forEach(function(t){d({kitId:t,scriptTimeout:3e3,async:!0})}),u.font_tracker_stylesheets.forEach(i)}};VoxMediaFontLoader(document);</script>
# <script type="text/javascript">
#
#   if (!window.pageloadId) {
#     window.pageloadId = (crypto.randomUUID) ? crypto.randomUUID() : ([1e7]+-1e3+-4e3+-8e3+-1e11).replace(/[018]/g, function (c)  { return (c ^ crypto.getRandomValues(new Uint8Array(1))[0] & 15 >> c / 4).toString(16);} );
#   }
#
#   try {
#     Reflect.setPrototypeOf(document, new Proxy(Reflect.getPrototypeOf(document), {
#       set(target, key, value, thisArg) {
#         try {
#           if (key === 'cookie') {
#             if (initialDataLayer && value.startsWith('_gaexp=')) {
#               const decoded = decodeURIComponent(value);
#               const optimizeExperiments = [...decoded.matchAll(/([\w-]{22})\.\d{5}\.(\d{1})/g)]
#               let ids = [];
#               let variants = [];
#               optimizeExperiments.forEach((exp) => { ids.push(exp[1]); variants.push(exp[2]); } )
#               // let's add it to both the dataLayer and the initialDataLayer
#               initialDataLayer.experimentIds = ids;
#               initialDataLayer.experimentVariants = variants;
#               dataLayer.push({'experimentIds': ids});
#               dataLayer.push({'experimentVariants': variants});
#             }
#           }
#         } catch (e) {
#           console.error(`Error inspecting document property '${key}' assignment: ${e}`);
#         } finally { // always set the property via the original object
#           return Reflect.set(...arguments);
#         }
#       }
#     }));
#   } catch (e) {
#     console.error(`Unable to reflect and proxy document.cookie: ${e}`);
#   }
#
#   const initialDataLayer = {"Network":"sbnation","Community":"dknetwork.draftkings","root_domain":"sbnation.com","GA Primary ID":"UA-1367699-1","GA Secondary ID":"UA-144904641-1","GA CrossDomains":"7500toholte.sbnation.com,aseaofblue.com,acmepackingcompany.com,addictedtoquack.com,allaboutthejersey.com,allforxi.com,alligatorarmy.com,amazinavenue.com,americanninjawarriornation.com,anchorofgold.com,anddownthestretchtheycome.com,andthevalleyshook.com,anonymou
bnation.com,bayarea.sbnation.com,boston.sbnation.com,chicago.sbnation.com,cleveland.sbnation.com,sbncollegehockey.com,dallas.sbnation.com,dc.sbnation.com,denver.sbnation.com,detroit.sbnation.com,houston.sbnation.com,kansascity.sbnation.com,losangeles.sbnation.com,minnesota.sbnation.com,newyork.sbnation.com,philly.sbnation.com,pittsburgh.sbnation.com,seattle.sbnation.com,stlouis.sbnation.com,tampabay.sbnation.com,sbnation.com,serpentsofmadonnina.com,shakinthesouthland.com,silvera ...
#   initialDataLayer.pageloadId = window.pageloadId;
#   dataLayer = [initialDataLayer];
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W8JKW6');</script>
# <!-- End Google Tag Manager -->
# <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://stats.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="https://cdn.permutive.com" rel="dns-prefetch"/>
# <link href="https://mb.moatads.com" rel="dns-prefetch"/>
# <script>
#   var concertAdsQueue = concertAdsQueue || [];
#   if (!window.pageloadId) {
#     window.pageloadId = (crypto.randomUUID) ? crypto.randomUUID() : ([1e7]+-1e3+-4e3+-8e3+-1e11).replace(/[018]/g, function (c)  { return (c ^ crypto.getRandomValues(new Uint8Array(1))[0] & 15 >> c / 4).toString(16);} );
#   }
#   CONCERT_ADS_CONFIG = {"production":true,"slug":"/172968584,21717748068/sbn/general/dknetwork.draftkings.com","dfpVariables":{"network":["sbn"],"affiliation":["general"],"unison":[true],"entry_id":[23489772],"entry_type":["article"],"entry_slug":["2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule"],"entry_author":["Collin Sherwin","Nick Simon"],"entry_blurb":["We have CFB win totals for the upcoming 2023 season and we go over them below. Spoiler alert: the Dawgs are at the top yet again."],"entry_title":["College football win totals for the 2023 season from DraftKings Sportsbook"],"entry_published_date":["2023-05-16T10:44:07.000-07:00"],"entry_group":["front-page","ncaa-football","ncaa-odds-lines"],"page_type":["interior_page"],"keywords":["college","football","win","totals","over","under","wins","for","every","team","in","fbs","georgia","alabama","usc","more","draftkings","network","front-page","ncaa-football","ncaa-odds-lines"]},"isUnison":true,"is_unison":true,"prebid":{},"slots":[],"adConfigurationUrl":"https://concertads-configs.vox-cdn.com/sbn/sbn/draftkingsnation/config.json"}
#   CONCERT_ADS_CONFIG.pageload_id = window.pageloadId;
#   CONCERT_ADS_CONFIG.dfpVariables.pageload_id = window.pageloadId;
# </script>
# <link data-chorus-theme="chorus" href="https://www.sbnation.com/style/community/763/f1c5ca8a6a6361aa4c96b58ae89dbe84/chorus.css" media="all" rel="stylesheet"/>
# <meta content="https://www.sbnation.com/style/community/763/4c6f3181c8880567530bd57d6c9d4165/tools.css" name="style-tools"/>
# <script async="async" crossorigin="anonymous" integrity="sha256-+y7a2yv6w/RCmU62f8R4z3uY73nsf/MzauaMCMKdW2o= sha384-5ywGFt4DUfB9lLwIM742pe2ttwjBjEcClp+YCL/gDGwGRalkqJ80QD9sOqvvFOsK" src="https://cdn.vox-cdn.com/packs/js/concert_ads-f9356680998b2fa897da.js"></script>
# <script type="text/javascript">
#   function instantiateConcertAds() {
#     var concertAdsConfig = {
#       cmd: window.concertAdsQueue
#     };
#
#     for (var property in window.CONCERT_ADS_CONFIG) {
#       concertAdsConfig[property] = window.CONCERT_ADS_CONFIG[property];
#     }
#
#     window.concertAds = new ConcertAds(concertAdsConfig);
#   }
# </script>
# <script async="" onload="instantiateConcertAds()" src="https://cdn.concert.io/lib/concert-ads/v2-latest/concert_ads.js"></script>
# <script async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script async="" src="https://cdn.concert.io/lib/concert-concierge.2.8.0.min.js"></script>
# <script defer="" src="https://z.moatads.com/voxprebidheader841653991752/moatheader.js" type="text/javascript"></script>
# <meta content="D385D0326A3AE144205C298DB34B4E94" name="msvalidate.01">
# <meta content="We have CFB win totals for the upcoming 2023 season and we go over them below. Spoiler alert: the Dawgs are at the top yet again." name="description">
# <link href="https://dknetwork.draftkings.com/2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule" rel="canonical">
# <meta content="We have CFB win totals for the upcoming 2023 season and we go over them below. Spoiler alert: the Dawgs are at the top yet again." property="og:description"/>
# <meta content="549923288395304" property="fb:app_id"/>
# <meta content="https://cdn.vox-cdn.com/thumbor/vmXmt8lmPD9mnNaN7iwNWX36a14=/0x0:5640x2953/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/24661307/usa_today_19756225.jpg" property="og:image"/>
# <meta content="NCAA Football: CFP National Championship-Texas Christian at Georgia" property="og:image:alt"/>
# <meta content="630" property="og:image:height"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="DraftKings Network" property="og:site_name"/>
# <meta content="College football win totals for the 2023 season from DraftKings Sportsbook" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://dknetwork.draftkings.com/2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://dknetwork.draftkings.com/2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule" name="twitter:url"/>
# <meta content="College football win totals for the 2023 season from DraftKings Sportsbook" name="twitter:title"/>
# <meta content="We have CFB win totals for the upcoming 2023 season and we go over them below. Spoiler alert: the Dawgs are at the top yet again." name="twitter:description"/>
# <meta content="https://cdn.vox-cdn.com/thumbor/WvOI72nGwO8QDk2rTB3Jh-UmeJo=/0x0:5640x2820/fit-in/1200x600/cdn.vox-cdn.com/uploads/chorus_asset/file/24661307/usa_today_19756225.jpg" name="twitter:image"/>
# <meta content="sbnation" name="twitter:site"/>
# <meta content="NCAA Football: CFP National Championship-Texas Christian at Georgia" name="twitter:image:alt"/>
# <meta content="College football win totals for the 2023 season from DraftKings Sportsbook" name="parsely-title"/>
# <meta content="https://dknetwork.draftkings.com/2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule" name="parsely-link"/>
# <meta content="post" name="parsely-type"/>
# <meta content="https://cdn.vox-cdn.com/thumbor/eY-9E65fIjYPdW_lkwjTJcgcDNs=/0x0:5640x3173/1600x900/cdn.vox-cdn.com/uploads/chorus_image/image/72285374/usa_today_19756225.0.jpg" name="parsely-image-url"/>
# <meta content="2023-05-16T10:44:07-07:00" name="parsely-pub-date"/>
# <meta content="ncaa-odds-lines" name="parsely-section"/>
# <meta content="dknation,front-page,ncaa-football,ncaa-odds-lines" name="parsely-tags"/>
# <meta content="Collin Sherwin" name="parsely-author"/>
# <meta content="Nick Simon" name="parsely-author"/>
# <meta content="max-image-preview:large" name="robots">
# <script async="" defer="" src="https://go.metabet.io/js/global.js?siteID=draftkings-light:dknation"></script>
# <link href="https://cdn.vox-cdn.com/dev/uploads/chorus_asset/file/8108502/sandbox-www-data-ip-10-0-0-66_/sandbox_64.0.ico" rel="shortcut icon"/>
# <link href="https://cdn.vox-cdn.com/dev/uploads/chorus_asset/file/8108503/sandbox-www-data-ip-10-0-0-66_/sandbox_favicon-192x192.0.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://cdn.vox-cdn.com/dev/uploads/chorus_asset/file/8108504/sandbox-www-data-ip-10-0-0-66_/sandbox_favicon-180x180.0.png" rel="apple-touch-icon" sizes="180x180"/>
# <meta content="https://cdn.vox-cdn.com/dev/uploads/chorus_asset/file/8108505/sandbox-www-data-ip-10-0-0-66_/sandbox_favicon-144x144.0.png" name="msapplication-TileImage"/>
# <meta content="#f7760d" name="msapplication-TileColor"/>
# <meta content="" name="theme-color"/>
# <link href="https://dknetwork.draftkings.com/platform/amp/2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule" rel="amphtml"/>
# <script class="coral-script" defer="" src="https://sbnation.coral.coralproject.net/assets/js/count.js?v=1626303173"></script>
# <link href="/rss/index.xml" rel="alternate" title="DraftKings Network" type="application/rss+xml">
# <script type="application/ld+json">
#   [{"@context":"https://schema.org","@type":"NewsArticle","mainEntityOfPage":"https://dknetwork.draftkings.com/2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule","url":"https://dknetwork.draftkings.com/2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule","headline":"College football win totals 2023: Over under wins for every team in FBS; Georgia, Alabama, USC, more","description":"We have CFB win totals for the upcoming 2023 season and we go over them below. Spoiler alert: the Dawgs are at the top yet again.","speakable":{"@type":"SpeakableSpecification","xpath":["/html/head/title","/html/head/meta[@name='description']/@content"]},"datePublished":"2023-05-16T10:44:07-07:00","dateModified":"2023-05-16T11:06:25-07:00","author":[{"@type":"Person","name":"Collin Sherwin"},{"@type":"Person","name":"Nick Simon"}],"article_body":"We’re still over three months away from the start of the 2023 college football season, but we finally have FBS win totals courtesy of DraftKings Sportsbook. To no surprise, the team with the highest win total is the two-time defending national champions in \u003ca href=\"https://sportsbook.draftkings.com/teams/college-football/georgia-bulldogs--odds\" data-vars-analytics-link-source=\"encore\" data-vars-analytics-link-url=\"https://sportsbook.draftkings.com/teams/college-football/georgia-bulldogs--odds\"\u003eGeorgia\u003c/a\u003e at 11.5. The Bulldogs have shown an ability to reload even after losing tons of elite talent to the NFL Draft over the past few years and a favorable schedule could make another 12-0 regular season a possibility. Right underneath the Dawgs are usual College Football Playoff contenders in \u003ca href=\"https://sportsbook.draftkings.com/teams/college-football/alabama-crimson-tide--odds\" data-vars-analytics-link-source=\"encore\" data-vars-analytics-link-url=\"https://sportsbook.draftkings.com/teams/college-football/alabama-crimson-tide--odds\"\u003eAlabama\u003c/a\u003e, \u003ca href=\"https://sportsbook.draftkings.com/teams/college-football/michigan-wolverines--odds\" data-vars-analytics-link-source=\"encore\" data-vars-analytics-link-url=\"https://sportsbook.draftkings.com/teams/college-football/michigan-wolverines--odds\"\u003eMichigan\u003c/a\u003e, and \u003ca href=\"https://sportsbook.draftkings.com/teams/college-football/ohio-state-buckeyes--odds\" data-vars-analytics-link-source=\"encore\" data-vars-analytics-link-url=\"https://sportsbook.draftkings.com/teams/college-football/ohio-state-buckeyes--odds\"\u003eOhio State\u003c/a\u003e, all of whom check in at 10.5. The Crimson Tide and Buckeyes will be breaking in new quarterbacks after the departures of Bryce Young and CJ Stroud. Meanwhile, the Wolverines will have QB JJ McCarthy back under center as well as preseason Heisman Trophy candidate Blake Corum at running back. A trendy playoff pick in \u003ca href=\"https://sportsbook.draftkings.com/teams/college-football/florida-state-seminoles--odds\" data-vars-analytics-link-source=\"encore\" data-vars-analytics-link-url=\"https://sportsbook.draftkings.com/teams/college-football/florida-state-seminoles--odds\"\u003eFlorida State\u003c/a\u003e opens at 10 while fellow powerhouses like \u003ca href=\"https://sportsbook.draftkings.com/teams/college-football/lsu-tigers--odds\" data-vars-analytics-link-source=\"encore\" data-vars-analytics-link-url=\"https://sportsbook.draftkings.com/teams/college-football/lsu-tigers--odds\"\u003eLSU\u003c/a\u003e, \u003ca href=\"https://sportsbook.draftkings.com/teams/college-football/usc-trojans--odds\" data-vars-analytics-link-source=\"encore\" data-vars-analytics-link-url=\"https://sportsbook.draftkings.com/teams/college-football/usc-trojans--odds\"\u003eUSC\u003c/a\u003e and \u003ca href=\"https://sportsbook.draftkings.com/teams/college-football/texas-longhorns--odds\" data-vars-analytics-link-source=\"encore\" data-vars-analytics-link-url=\" ...
# </script>
# <meta content="ncaa-football" name="outbrainsection"/>
# </link></meta></link></meta></meta></meta></meta></meta></head>
# <!--[if lte IE 9]><body class="ie9"><![endif]-->
# <!--[if gte IE 10]><body class="ie"><![endif]-->
# <body class="entry_key_unison_standard entry_layout_unison_main entry_template_standard" data-entry-id="23489772">
# <a class="sr-only link-skip" href="#content">Skip to main content</a>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-W8JKW6" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <svg height="0" style="position:absolute;display:none;" width="0"><symbol id="icon-clock" viewbox="90 0 689 645" xmlns="http://www.w3.org/2000/svg"><title>clock</title>
# <path d="M489.1 322.5c0 15-5.4 27.9-16 38.6-10.7 10.7-23.6 16-38.6 16-23.7 0-40.3-10.9-49.9-32.8h-125c-6.4 0-11.6-2.1-15.7-6.1-4-4.1-6.1-9.3-6.1-15.7 0-6.4 2.1-11.6 6.1-15.7 4.1-4.1 9.4-6.1 15.8-6.1h125c5.9-13.2 15.3-22.5 28-28V125.8c0-6.4 2.1-11.6 6.1-15.7 4.1-4.1 9.3-6.1 15.7-6.1 6.4 0 11.6 2 15.7 6.1s6.1 9.3 6.1 15.7v146.8c21.9 9.5 32.9 26.1 32.8 49.9zm-54.6-306c84.2 0 156.3 29.9 216.2 89.8 59.9 59.9 89.8 131.9 89.8 216.2s-29.9 156.3-89.8 216.2c-59.9 59.9-131.9 89.8-216.2 89.8s-156.3-29.9-216.2-89.8c-59.9-59.9-89.8-131.9-89.8-216.2s29.9-156.3 89.8-216.2c59.9-59.9 132-89.8 216.2-89.8zm0 546.4c66.5 0 123.2-23.4 170.1-70.4 46.9-46.9 70.4-103.6 70.4-170.1s-23.4-123.2-70.4-170.1C557.7 105.5 501 82.1 434.5 82.1s-123.2 23.4-170.1 70.4C217.5 199.4 194 256.1 194 322.6s23.4 123.2 70.4 170.1c46.9 46.8 103.6 70.2 170.1 70.2z"></path></symbol><symbol id="icon-close" viewbox="0 0 1000 1000" xmlns="http://www.w3.org/2000/svg"><path d="M638.6 500l322.7-322.7c38.3-38.3 38.3-100.3 0-138.6S861 .4 822.7 38
# <div class="l-wrapper">
# <div class="c-global-header__logo">
# <a data-analytics-link="home" href="/" id="chorus-brand">
# <span class="sr-only">DraftKings Network homepage</span>
# <span aria-hidden="true" class="c-global-header__logo-large" tabindex="-1">
# <img class="" src="https://cdn.vox-cdn.com/uploads/chorus_asset/file/24724190/DKN_Tag_White_Screen_RGB_v1.png"/>
# </span>
# <span class="c-global-header__logo-small">
# <img class="" src="https://cdn.vox-cdn.com/uploads/chorus_asset/file/24724190/DKN_Tag_White_Screen_RGB_v1.png"/>
# </span>
# </a>
# </div>
# <div class="c-global-header__actions">
# <div aria-labelledby="global-header__search--label" class="c-global-header__search">
# <h2 class="sr-only" id="global-header__search--label">Site search</h2>
# <button class="c-global-header__search-trigger" type="submit">
# <span class="sr-only">Search</span>
# <svg aria-hidden="true" class="c-global-header__login-svg" role="img"><title>Search</title>
# <use xlink:href="#icon-search"></use></svg>
# </button>
# </div>
# </div>
# <nav aria-labelledby="global-header__links--label" class="c-global-header__links">
# <h2 class="sr-only" id="global-header__links--label">DraftKings Network main menu</h2>
# <ul>
# <li class="c-global-header__link" data-nav-item-id="news" data-nav-list-trigger="news">
# <a class="c-global-header__label">
#               News
#
#                 <span class="c-global-header__link-arrow"><svg role="img"><use xlink:href="#icon-norgie-down"></use></svg></span>
# </a>
# </li>
# <li class="c-global-header__link" data-nav-item-id="betting-picks" data-nav-list-trigger="betting-picks">
# <a href="/sports-betting-picks">
#               Betting Picks
#
#                 <span class="c-global-header__link-arrow"><svg role="img"><use xlink:href="#icon-norgie-down"></use></svg></span>
# </a>
# </li>
# <li class="c-global-header__link hidden" data-nav-item-id="fantasy-advice" data-nav-list-trigger="fantasy-advice">
# <a href="/fantasy-advice">
#               Fantasy Advice
#
#                 <span class="c-global-header__link-arrow"><svg role="img"><use xlink:href="#icon-norgie-down"></use></svg></span>
# </a>
# </li>
# <li class="c-global-header__link hidden" data-nav-item-id="shows" data-nav-list-trigger="shows">
# <a href="/pages/draftkings-network">
#               Shows
#
#                 <span class="c-global-header__link-arrow"><svg role="img"><use xlink:href="#icon-norgie-down"></use></svg></span>
# </a>
# </li>
# <li class="c-global-header__link hidden" data-nav-item-id="collectibles" data-nav-list-trigger="collectibles">
# <a class="c-global-header__label">
#               Collectibles
#
#                 <span class="c-global-header__link-arrow"><svg role="img"><use xlink:href="#icon-norgie-down"></use></svg></span>
# </a>
# </li>
# <li class="c-global-header__link hidden" data-nav-item-id="dk-games" data-nav-list-trigger="dk-games">
# <a class="c-global-header__label">
#               DK Games
#
#                 <span class="c-global-header__link-arrow"><svg role="img"><use xlink:href="#icon-norgie-down"></use></svg></span>
# </a>
# </li>
# <li class="c-global-header__link-more" data-nav-list-trigger="more">
# <a class="c-global-header__label">
#             More
#             <span class="c-global-header__link-arrow"><svg role="img"><use xlink:href="#icon-norgie-down"></use></svg></span>
# <span class="c-global-header__link-hamburger"><svg role="img"><use xlink:href="#icon-hamburger"></use></svg></span>
# </a>
# </li>
# </ul>
# </nav>
# <div class="c-global-header__primary-community network-logo--darken">
# <a href="https://www.sbnation.com/blogs">
#           All 300 communities <span class="c-global-header__primary-community-tag">on</span>
# <svg enable-background="new 0 0 1000 137.7" id="Layer_1" version="1.1" viewbox="0 0 1000 137.7" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <title>Horizontal - White</title>
# <path d="M245.3,68.1c11.5,0,20.8-9.1,21.1-20.6c0-7.2,0-12.7,0-12.7C266.5,13.9,253,0,233.7,0h-95v137.7H234
# 	c16.3,0,32.5-12.5,32.5-33.7V89.2C266.5,77.5,257,68.1,245.3,68.1z M216,98.6c0,1.7-1.3,3-3,3h-23.8v-15h23.6c1.8,0,3.2,1.5,3.2,3.2
# 	c0,0,0,0,0,0V98.6z M216,46.2c0,1.8-1.5,3.3-3.3,3.3h-23.5V36.1h23.5c1.9,0,3.4,1.5,3.4,3.4L216,46.2z" fill="#FFFFFF"></path>
# <path d="M127.7,42.8v-9.1c0-6.6-1.8-13-5.1-18.7l0.1-0.2C117,6,107.4,0.5,96.9,0h-0.1c-0.4,0-0.8,0-1.2,0H32.3
# 	C14.5,0,0,14.5,0,32.3v18.7l0,0v8.8c0,14.9,12,26.9,26.9,26.9c0,0,0,0,0,0h46.9c1.9,0,3.4,1.5,3.4,3.5l0,0v8c0,1.9-1.6,3.5-3.5,3.5
# 	H50.5v-6.6H0v10.2c0,6.2,1.8,12.3,5.1,17.5l-0.1,0.2c5.6,8.8,15.3,14.4,25.7,14.8h0.1c0.4,0,0.8,0,1.2,0h63.3
# 	c17.8,0,32.3-14.4,32.3-32.3l0,0V86.8l0,0V76.4c0-14.9-12-26.9-26.9-26.9h0H53.9c-1.9,0-3.4-1.5-3.4-3.5l0,0v-6.5
# 	c0-1.9,1.6-3.5,3.5-3.5h23.4v6.7H127.7z" fill="#FFFFFF"></path>
# <rect fill="#FFFFFF" height="137.7" width="50.5" x="674.1"></rect>
# <polygon fill="#FFFFFF" points="664.4,0 549.2,0 549.2,36.3 581.6,36.3 581.6,137.7 632,137.7 632,36.3 664.4,36.3 "></polygon>
# <path d="M830.5,0h-62.8c-17.8,0-32.3,14.5-32.3,32.3v73.1c0,17.8,14.5,32.3,32.3,32.3h62.8
# 	c17.8,0,32.3-14.5,32.3-32.3V32.3C862.8,14.5,848.4,0,830.5,0L830.5,0z M812.4,98.4c0,1.8-1.5,3.2-3.2,3.2h-20
# 	c-1.8,0-3.2-1.5-3.2-3.2v-59c0-1.8,1.5-3.2,3.2-3.2h20c1.8,0,3.2,1.5,3.2,3.2V98.4z" fill="#FFFFFF"></path>
# <path d="M951,0v49.7L915.8,9.5c-5.1-6-12.6-9.5-20.5-9.5h-21.5v137.7h49V87.8l35.2,40.3c5.1,6,12.6,9.5,20.5,9.5
# 	h21.5V0H951z" fill="#FFFFFF"></path>
# <path d="M354.7,0v49.7L319.4,9.5c-5.1-6-12.6-9.5-20.5-9.5h-21.5v137.7h49V87.8l35.2,40.3c5.1,6,12.6,9.5,20.5,9.5
# 	h21.5V0H354.7z" fill="#FFFFFF"></path>
# <path d="M531.6,17.9C527.8,7.2,517.7,0,506.3,0h-70v36.3h10.5l-35.2,101.3h50.6l7.2-20.8H516l7.2,20.9h50L531.6,17.9
# 	z M492.6,49.6l10.8,31h-21.4L492.6,49.6z" fill="#FFFFFF"></path>
# </svg>
# </a>
# </div>
# <div class="p-input-header c-global-header__search-menu" data-analytics-class="search">
# <form action="/search" data-analytics-class="search" id="global_search_form" method="GET">
# <input class="p-input-header__input" name="q" placeholder="Search"/>
# <input class="p-input-header__link p-button" type="submit" value="Search"/>
# </form>
# </div>
# </div>
# </header>
# <section class="c-nav-list" data-cdata='{"tab_id":"more"}' data-cid="site/nav_list-1687972309_4454_43756">
# <div class="c-nav-list__inner">
# <ul class="c-nav-list__main" data-nav-list-id="more">
# <li data-nav-item-id="news" data-nav-list-id="news">
# <span class="c-nav-list__label">
#           News
#
#             <span class="c-nav-list__arrow-down"><svg role="img"><use xlink:href="#icon-norgie-down"></use></svg></span>
#
# <li><a href="https://www.voxmedia.com/vox-advertising" rel="nofollow">Advertise with us</a></li>
# <li><a href="https://jobs.voxmedia.com" rel="nofollow">Jobs @ Vox Media</a></li>
# </ul>
# </div>
# </div>
# <div class="l-wrapper c-footer__wrapper">
# <div class="c-footer__section c-footer__section-copy">
#         © 2023 <a href="https://www.voxmedia.com" rel="nofollow">Vox Media</a>, LLC. All Rights Reserved
#
#           <br/><p style="text-align: left; margin: 20px auto 3px; font-size:15px; font-weight:bold">Gambling Problem? Call (800) 327-5050 or visit gamblinghelpline.ma.org (MA), Call 877-8-HOPENY/text HOPENY (467369) (NY),</p> <p style="text-align: left;font-size:12px; font-weight: bold">If you or someone you know has a gambling problem, crisis counseling and referral services can be accessed by calling 1-800-GAMBLER (1-800-426-2537) (CO/IL/IN/LA/MD/MI/NJ/OH/PA/TN/WV/WY), 1-800-NEXT STEP (AZ), 1-800-522-4700 (KS/NH), 888-789-7777/visit ccpg.org (CT), 1-800-BETS OFF (IA), visit OPGR.org (OR), or 1-888-532-3500 (VA). </p> <p style="text-align: left;font-size:12px;">Odds and lines subject to change. 21+ (18+ NH/WY). Physically present in AZ/CO/CT/IL/IN/IA/KS/LA (select parishes)/MA/MD/MI/NH/NJ/NY/OH/OR/PA/TN/VA/WV/WY only. Void in ONT. Eligibility restrictions apply. See terms at draftkings.com/sportsbook. On behalf of Boot Hill Casino &amp; resort (KS).</p>
# </div>
# </div>
# </footer>
# <div class="c-tab-bar" data-cdata="{}" data-cid="site/tab_bar/index-1687972309_6578_43759">
# <a class="c-tab-bar__logo" href="/">
# <?xml version="1.0" encoding="UTF-8"?>
# <svg data-name="Layer 1" id="Layer_1" viewbox="0 0 180 180" xmlns="http://www.w3.org/2000/svg">
# <defs>
# <style>
#       .cls-1 {
#         fill: #282b32;
#       }
#     </style>
# </defs>
# <g id="DKN">
# <path class="cls-1" d="m155.04,59.99v14.26l-14.36-14.26h-20.64s-20.81,0-20.81,0l-14.26,14.26v-14.26h-25.02v23.09c-3.12-13.24-15.01-23.09-29.2-23.09H-.06v60.01h30.82c14.19,0,26.07-9.86,29.2-23.09v23.09h24.89l.12-14.27,14.21,14.27h45.84v-14.27l14.27,14.27h20.76v-60.01h-25.02Zm-115.32,35.53c-.11.4-.54.61-.93.45-3-1.23-6.4-1.54-9.78-.68s-6.22,2.75-8.27,5.26c-.26.32-.74.34-1.03.05l-9.8-10.22s2.14-.6,4.03.56c1.25-1.06,2.91-.75,2.91-.75.64,1.05.17,2.86.17,2.86l3.96-1.5c.27-.1.5-.29.66-.53l3.32-5.09s-1.86,0-2.66-.93c0,0,.49-1.2,1.88-2.08-.55-2.15.67-4.01.67-4.01,0,0,1.96,1.05,2.51,3.2,1.64.11,2.64.93,2.64.93-.27,1.2-1.9,2.08-1.9,2.08l5.35,2.89c.26.14.55.19.84.15l4.2-.57s-1.28-1.37-1.22-2.6c0,0,1.31-1.07,2.91-.73,1.1-1.93,3.27-2.42,3.27-2.42l-3.73,13.65Zm80.32,10.21l-15.74-15.74,15.74-15.74v31.47Z"></path>
# </g>
# </svg>
# </a>
# <div aria-labelledby="heading-label--wkivom3n" class="c-social-buttons" data-analytics-placement="sticky" data-cdata='{"entry_id":23489772,"services":["twitter","facebook"],"base_url":"https://dknetwork.draftkings.com/2023/5/16/23725731/ncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule"}' data-cid="site/social_buttons_list-1687972309_6771_43758">
# <h2 class="sr-only" id="heading-label--wkivom3n">Share this story</h2>
# <ul>
# <li>
# <a class="c-social-buttons__item c-social-buttons__twitter" data-analytics-social="twitter" href="https://twitter.com/intent/tweet?counturl=https%3A%2F%2Fdknetwork.draftkings.com%2F2023%2F5%2F16%2F23725731%2Fncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule&amp;text=College+football+win+totals+for+the+2023+season+from+DraftKings+Sportsbook&amp;url=https%3A%2F%2Fdknetwork.draftkings.com%2F2023%2F5%2F16%2F23725731%2Fncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule&amp;via=sbnation">
# <svg class="p-svg-icon c-social-buttons__svg" role="img"><use xlink:href="#icon-twitter"></use></svg>
# <span class="c-social-buttons__text">
#                 Twitter
#               </span>
# </a>
# </li>
# <li>
# <a class="c-social-buttons__item c-social-buttons__facebook" data-analytics-social="facebook" href="https://www.facebook.com/sharer/sharer.php?text=College+football+win+totals+for+the+2023+season+from+DraftKings+Sportsbook&amp;u=https%3A%2F%2Fdknetwork.draftkings.com%2F2023%2F5%2F16%2F23725731%2Fncaa-football-win-totals-2023-over-under-alabama-georgia-usc-texas-lsu-sec-schedule">
# <svg class="p-svg-icon c-social-buttons__svg" role="img"><use xlink:href="#icon-facebook"></use></svg>
# <span class="c-social-buttons__text">
#                 Facebook
#               </span>
# </a>
# </li>
# </ul>
# </div>
# <span class="c-tab-bar__sponsorship"></span>
# </div>
# </div>
# <script async="async" crossorigin="anonymous" integrity="sha256-IhCIath7e9ssLlX7hTmf6/u7Jz8up/43816/FApX2bA= sha384-yoy3HnV3pCJLy48hsUx+yKolMYTdW0ORgzCv9GyP2RFGtai0/ZU5dmYkwUOEmf9H" src="https://cdn.vox-cdn.com/packs/js/chorus-60b94726193dd68a6e08.js"></script>
# <div id="amzn-assoc-ad-c86ecff2-0781-48c9-a698-200b0643c35a"></div><script defer="" src="https://z-na.associates-amazon.com/onetag/v2?MarketPlace=US&amp;instanceId=c86ecff2-0781-48c9-a698-200b0643c35a"></script>
# <!-- Phonograph -->
# <script async="async" defer="defer" id="phonograph-pickup" src="https://phonograph2.voxmedia.com/pickup.js?v=1529075019264"></script>
# <script>
#       var phonographEvents = phonographEvents || [];
#       (function() {
#         var continent = document.cookie.match(/_chorus_geoip_continent=([^;]+)/i) || [];
#         var data = { 'Page Title':document.title, 'GA Track Prefix':'t1.', 'geoip_continent': continent[1] };
#         var dataLayer = window.dataLayer || [];
#         dataLayer
#           .filter(function(m) { return !!m['Network'] })
#           .forEach(function(m) {
#             Object.keys(m).forEach(function(k) { data[k] = m[k] });
#           });
#
#         var userid = data['Logged in Status'];
#         data['User ID'] = (typeof userid === 'number') ? userid : null;
#         phonographEvents.push(['pageload', data]);
#       })();
#     </script>
# <!-- End Phonograph -->
# <script defer="" id="parsely-cfg" src="//cdn.parsely.com/keys/dknetwork.draftkings.com/p.js"></script>
# <style type="text/css">
#
# .sticky-ad .josh_wrap hr.border, .sticky-ad .josh_wrap hr, .sticky-ad .josh_wrap h2, .sticky-ad .josh_wrap .description {
#   display:  none ;
# }
#
# </style>
# </body></html>
# <script type="text/javascript">
#   window.onload = function() {
#     var links = document.querySelector('.c-entry-content').querySelectorAll('p [has-subtag="true"], li [has-subtag="true"], div [has-subtag="true"]');
#     links.forEach(link => {
#       var subtagData = link.getAttribute('data-cdata');
#       if (subtagData) {
#         window.Subtags(link, JSON.parse(subtagData));
#       }
#     });
#   }
# </script>

# %%
# Separate our headers

headers = soup.findAll('th')[:3]
column_headers = [i.getText() for i in headers]
column_headers
# Out:
# ['Team', 'Over', 'Under']

# %%
# Getting the column headers for our code

content = soup.findAll('tbody')[0]
content = [i.getText()[0:] for i in content.findAll('td')]
content
# Out:
# ['Air Force',
#  '8.5 +125',
#  '8.5 −150',
#  'Akron',
#  '3.5 −120',
#  '3.5 −105',
#  'Alabama',
#  '10.5 +135',
#  '10.5 −155',
#  'Appalachian State',
#  '6.5 −110',
#  '6.5 −115',
#  'Arizona',
#  '5 −120',
#  '5 +100',
#  'Arizona State',
#  '5 +120',
#  '5 −140',
#  'Arkansas',
#  '7 +100',
#  '7 −120',
#  'Arkansas State',
#  '4.5 −145',
#  '4.5 +120',
#  'Army',
#  '6 +105',
#  '6 −130',
#  'Auburn',
#  '6.5 −135',
#  '6.5 +115',
#  'Ball State',
#  '4.5 −120',
#  '4.5 −105',
#  'Baylor',
#  '7.5 +135',
#  '7.5 −160',
#  'Boise State',
#  '9 +140',
#  '9 −170',
#  'Boston College',
#  '5.5 −120',
#  '5.5 +100',
#  'Bowling Green',
#  '5 +105',
#  '5 −130',
#  'BYU',
#  '5.5 −120',
#  '5.5 +100',
#  'California',
#  '5 +110',
#  '5 −130',
#  'Central Michigan',
#  '5.5 −110',
#  '5.5 −115',
#  'Charlotte',
#  '2.5 −120',
#  '2.5 −105',
#  'Cincinnati',
#  '5.5 +110',
#  '5.5 −130',
#  'Clemson',
#  '9.5 −140',
#  '9.5 +120',
#  'Coastal Carolina',
#  '8 −120',
#  '8 −105',
#  'Colorado',
#  '3 −105',
#  '3 −115',
#  'Colorado State',
#  '4.5 −115',
#  '4.5 −110',
#  'Duke',
#  '6.5 +115',
#  '6.5 −135',
#  'East Carolina',
#  '5.5 +125',
#  '5.5 −150',
#  'Eastern Michigan',
#  '6.5 −145',
#  '6.5 +120',
#  'FIU',
#  '2.5 −145',
#  '2.5 +120',
#  'Florida',
#  '5.5 −105',
#  '5.5 −115',
#  'Florida State',
#  '10 −105',
#  '10 −115',
#  'Fresno State',
#  '8 −105',
#  '8 −120',
#  'Georgia',
#  '11.5 +130',
#  '11.5 −150',
#  'Georgia Southern',
#  '6 −110',
#  '6 −115',
#  'Georgia State',
#  '5.5 +105',
#  '5.5 −130',
#  'Georgia Tech',
#  '4.5 +120',
#  '4.5 −140',
#  'Hawaii (13 Games)',
#  '3.5 +115',
#  '3.5 −140',
#  'Houston',
#  '4.5 −110',
#  '4.5 −110',
#  'Illinois',
#  '6.5 −135',
#  '6.5 +115',
#  'Indiana',
#  '3.5 −135',
#  '3.5 +115',
#  'Iowa',
#  '7.5 −145',
#  '7.5 +125',
#  'Iowa State',
#  '5.5 −145',
#  '5.5 +125',
#  'Jacksonville State',
#  '5.5 −110',
#  '5.5 −115',
#  'James Madison',
#  '7.5 −140',
#  '7.5 +115',
#  'Kansas',
#  '6.5 +130',
#  '6.5 −150',
#  'Kansas State',
#  '8.5 +110',
#  '8.5 −130',
#  'Kent State',
#  '2.5 −120',
#  '2.5 −105',
#  'Kentucky',
#  '6.5 −145',
#  '6.5 +125',
#  'Liberty',
#  '9.5 +140',
#  '9.5 −165',
#  'Louisiana Tech',
#  '6.5 −135',
#  '6.5 +110',
#  'Louisiana-Lafayette',
#  '5.5 −110',
#  '5.5 −115',
#  'Louisville',
#  '8 +125',
#  '8 −145',
#  'LSU',
#  '9.5 +110',
#  '9.5 −130',
#  'Marshall',
#  '7 −110',
#  '7 −115',
#  'Maryland',
#  '7 −105',
#  '7 −115',
#  'Massachusetts',
#  '1.5 −180',
#  '1.5 +145',
#  'Miami FL',
#  '7.5 +120',
#  '7.5 −140',
#  'Miami OH',
#  '6.5 −110',
#  '6.5 −115',
#  'Michigan',
#  '10.5 −105',
#  '10.5 −115',
#  'Michigan State',
#  '5.5 +130',
#  '5.5 −150',
#  'Middle Tennessee',
#  '6.5 −125',
#  '6.5 +100',
#  'Minnesota',
#  '6.5 −125',
#  '6.5 +105',
#  'Mississippi State',
#  '6.5 +115',
#  '6.5 −135',
#  'Missouri',
#  '6.5 +125',
#  '6.5 −145',
#  'Navy',
#  '6.5 −135',
#  '6.5 +110',
#  'Nebraska',
#  '6 −120',
#  '6 +100',
#  'Nevada',
#  '3 −160',
#  '3 +135',
#  'New Mexico',
#  '4 +130',
#  '4 −155',
#  'New Mexico State (13 Games)',
#  '5 −120',
#  '5 −105',
#  'North Carolina',
#  '8.5 −125',
#  '8.5 +105',
#  'North Carolina State',
#  '6.5 −145',
#  '6.5 +125',
#  'North Texas',
#  '6.5 −115',
#  '6.5 −110',
#  'Northern Illinois',
#  '6.5 −110',
#  '6.5 −115',
#  'Northwestern',
#  '3.5 −125',
#  '3.5 +105',
#  'Notre Dame',
#  '9 +110',
#  '9 −130',
#  'Ohio',
#  '7 −120',
#  '7 −105',
#  'Ohio State',
#  '10.5 −105',
#  '10.5 −115',
#  'Oklahoma',
#  '9.5 −115',
#  '9.5 −105',
#  'Oklahoma State',
#  '9.5 −115',
#  '9.5 −105',
#  'Old Dominion',
#  '3.5 −120',
#  '3.5 −105',
#  'Ole Miss',
#  '6.5 +100',
#  '6.5 −120',
#  'Oregon',
#  '9.5 +100',
#  '9.5 −120',
#  'Oregon State',
#  '8 −135',
#  '8 +115',
#  'Penn State',
#  '9.5 −130',
#  '9.5 +110',
#  'Pittsburgh',
#  '6.5 −145',
#  '6.5 +115',
#  'Purdue',
#  '5.5 +105',
#  '5.5 −125',
#  'Rice',
#  '5 −115',
#  '5 −110',
#  'Sam Houston',
#  '4 −125',
#  '4 +100',
#  'San Diego State',
#  '7 −105',
#  '7 −120',
#  'San Jose State',
#  '5.5 −145',
#  '5.5 +120',
#  'SMU',
#  '8 −110',
#  '8 −115',
#  'South Alabama',
#  '8 −105',
#  '8 −120',
#  'South Carolina',
#  '6.5 −105',
#  '6.5 −115',
#  'South Florida',
#  '3.5 −120',
#  '3.5 −105',
#  'Southern Miss',
#  '5 +100',
#  '5 −125',
#  'Stanford',
#  '3 +100',
#  '3 −120',
#  'Syracuse',
#  '6.5 +105',
#  '6.5 −125',
#  'TCU',
#  '7.5 −125',
#  '7.5 +105',
#  'Temple',
#  '5 −140',
#  '5 +115',
#  'Tennessee',
#  '9.5 +130',
#  '9.5 −150',
#  'Texas',
#  '9.5 −115',
#  '9.5 −105',
#  'Texas A&M',
#  '7.5 −150',
#  '7.5 +130',
#  'Texas State',
#  '4.5 +110',
#  '4.5 −135',
#  'Texas Tech',
#  '7.5 +120',
#  '7.5 −140',
#  'Troy',
#  '8 −140',
#  '8 +115',
#  'Tulane',
#  '9.5 +120',
#  '9.5 −145',
#  'Tulsa',
#  '4 −115',
#  '4 −110',
#  'UAB',
#  '5 −130',
#  '5 +105',
#  'UCF',
#  '6.5 −150',
#  '6.5 +130',
#  'UCLA',
#  '8.5 +110',
#  '8.5 −130',
#  'UConn',
#  '5.5 +105',
#  '5.5 −130',
#  'ULM',
#  '3.5 +125',
#  '3.5 −150',
#  'UNLV',
#  '6 −105',
#  '6 −120',
#  'USC',
#  '9.5 −165',
#  '9.5 +140',
#  'Utah',
#  '8.5 +125',
#  '8.5 −145',
#  'Utah State',
#  '6 +130',
#  '6 −155',
#  'UTEP',
#  '5.5 +100',
#  '5.5 −125',
#  'Vanderbilt',
#  '3.5 −145',
#  '3.5 +125',
#  'Virginia',
#  '3.5 −115',
#  '3.5 −105',
#  'Virginia Tech',
#  '5 −115',
#  '5 −105',
#  'Wake Forest',
#  '6 −120',
#  '6 +100',
#  'Washington',
#  '9 −105',
#  '9 −115',
#  'Washington State',
#  '6.5 −120',
#  '6.5 +100',
#  'West Virginia',
#  '4.5 −140',
#  '4.5 +120',
#  'Western Kentucky',
#  '8.5 +125',
#  '8.5 −150',
#  'Western Michigan',
#  '3.5 +110',
#  '3.5 −135',
#  'Wisconsin',
#  '9 +125',
#  '9 −145',
#  'Wyoming',
#  '6.5 −125',
#  '6.5 +100']

# %% [markdown]
# Next, we need to transform this data into separate lists using the pattern of 'Team', 'Over', 'Under' in a for loop using the order of our content list to grab every third item from different starting points.

# %%
teams = []
Over = []
Under = []
for x in content[0::3]:
    teams.append(x)
for y in content[1::3]:
    Over.append(y)
for z in content[2::3]:
    Under.append(z)

# %% [markdown]
# Always good to double check and ensure all our data is there and even.

# %%
print("UNDER :", len(Under), 
      "OVER :", len(Over), 
      "TEAMS :", len(teams))
# Out:
# UNDER : 127 OVER : 127 TEAMS : 127

# %% [markdown]
# So there should be 133 teams in total, which means we're missing some (this is the QA part of the problem outlined above). I'll circle back to this issue once we have the dataframe together.
#
# For now, let's transform the data using a dataframe.

# %%
body = {'Team': teams,
        'Over': Over,
        'Under': Under}

df = pd.DataFrame(columns = column_headers, data = body)
df.head()
# Out:
#                 Team       Over      Under
# 0          Air Force   8.5 +125   8.5 −150
# 1              Akron   3.5 −120   3.5 −105
# 2            Alabama  10.5 +135  10.5 −155
# 3  Appalachian State   6.5 −110   6.5 −115
# 4            Arizona     5 −120     5 +100

# %% [markdown]
# Ok the data looks good, but the win totals combined with the different odds is causing a little confusion. I would prefer an apples to apples comparision so we will need to centralize our data around a similar odds -- let's transform our data to display +100 odds or 50% implied probability for each team. This way, if the odds are plus odds, like +125, they would be less likely than 50% to go over their total. And if odds are minus like -120, they would be more than 50% chance of getting their over. Thus, their total would be higher.
#
# Make sense? Let's manipulate some data.
#
# The following code splits out 'Over' column to separate the win totals from the vig number at the end of the column. We then clean the newly created column and convert to the appropriate datatype -- float.

# %%
# Split the "Over" column by space
df[['Over_Value', 'Over_Odds']] = df['Over'].str.split(' ', 1, expand=True)

# Split the "Under" column by space
df[['Under_Value', 'Under_Odds']] = df['Under'].str.split(' ', 1, expand=True)

# %%
df.head()
# Out:
#                 Team       Over      Under Over_Value Over_Odds Under_Value  \
# 0          Air Force   8.5 +125   8.5 −150        8.5      +125         8.5
# 1              Akron   3.5 −120   3.5 −105        3.5      −120         3.5
# 2            Alabama  10.5 +135  10.5 −155       10.5      +135        10.5
# 3  Appalachian State   6.5 −110   6.5 −115        6.5      −110         6.5
# 4            Arizona     5 −120     5 +100          5      −120           5
#
#   Under_Odds
# 0       −150
# 1       −105
# 2       −155
# 3       −115
# 4       +100

# %%
# Replace Unicode minus sign with hyphen-minus
df['Over_Odds'] = df['Over_Odds'].str.replace('−', '-')
df['Under_Odds'] = df['Under_Odds'].str.replace('−', '-')

# A function to split the values and store in separate columns
def split_values(row, column):
    value = row[column]
    if value.startswith('-'):
        return value[1:], '-'
    elif value.startswith('+'):
        return value[1:], '+'
    else:
        return value, ''

# Split the 'Over_Odds' column
df['Over_Value_Split'], df['Over_Sign'] = zip(*df.apply(lambda row: split_values(row, 'Over_Odds'), axis=1))

# Split the 'Under_Odds' column
df['Under_Value_Split'], df['Under_Sign'] = zip(*df.apply(lambda row: split_values(row, 'Under_Odds'), axis=1))

# Remove leading white space from the split values
df['Over_Value_Split'] = df['Over_Value_Split'].str.strip()
df['Under_Value_Split'] = df['Under_Value_Split'].str.strip()

# Convert the split values to the appropriate data types
df['Over_Value_Split'] = df['Over_Value_Split'].astype(float)
df['Under_Value_Split'] = df['Under_Value_Split'].astype(float)

# Display the updated dataframe
print(df)
# Out:
#                   Team       Over      Under Over_Value Over_Odds Under_Value  \
# 0            Air Force   8.5 +125   8.5 −150        8.5      +125         8.5
# 1                Akron   3.5 −120   3.5 −105        3.5      -120         3.5
# 2              Alabama  10.5 +135  10.5 −155       10.5      +135        10.5
# 3    Appalachian State   6.5 −110   6.5 −115        6.5      -110         6.5
# 4              Arizona     5 −120     5 +100          5      -120           5
# ..                 ...        ...        ...        ...       ...         ...
# 122      West Virginia   4.5 −140   4.5 +120        4.5      -140         4.5
# 123   Western Kentucky   8.5 +125   8.5 −150        8.5      +125         8.5
# 124   Western Michigan   3.5 +110   3.5 −135        3.5      +110         3.5
# 125          Wisconsin     9 +125     9 −145          9      +125           9
# 126            Wyoming   6.5 −125   6.5 +100        6.5      -125         6.5
#
#     Under_Odds  Over_Value_Split Over_Sign  Under_Value_Split Under_Sign
# 0         -150             125.0         +              150.0          -
# 1         -105             120.0         -              105.0          -
# 2         -155             135.0         +              155.0          -
# 3         -115             110.0         -              115.0          -
# 4         +100             120.0         -              100.0          +
# ..         ...               ...       ...                ...        ...
# 122       +120             140.0         -              120.0          +
# 123       -150             125.0         +              150.0          -
# 124       -135             110.0         +              135.0          -
# 125       -145             125.0         +              145.0          -
# 126       +100             125.0         -              100.0          +
#
# [127 rows x 11 columns]

# %%
df.head()
# Out:
#                 Team       Over      Under Over_Value Over_Odds Under_Value  \
# 0          Air Force   8.5 +125   8.5 −150        8.5      +125         8.5
# 1              Akron   3.5 −120   3.5 −105        3.5      -120         3.5
# 2            Alabama  10.5 +135  10.5 −155       10.5      +135        10.5
# 3  Appalachian State   6.5 −110   6.5 −115        6.5      -110         6.5
# 4            Arizona     5 −120     5 +100          5      -120           5
#
#   Under_Odds  Over_Value_Split Over_Sign  Under_Value_Split Under_Sign
# 0       -150             125.0         +              150.0          -
# 1       -105             120.0         -              105.0          -
# 2       -155             135.0         +              155.0          -
# 3       -115             110.0         -              115.0          -
# 4       +100             120.0         -              100.0          +

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Team               127 non-null    object
#  1   Over               127 non-null    object
#  2   Under              127 non-null    object
#  3   Over_Value         127 non-null    object
#  4   Over_Odds          127 non-null    object
#  5   Under_Value        127 non-null    object
#  6   Under_Odds         127 non-null    object
#  7   Over_Value_Split   127 non-null    float64
#  8   Over_Sign          127 non-null    object
#  9   Under_Value_Split  127 non-null    float64
#  10  Under_Sign         127 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 11.0+ KB

# %%
# Convert Over_Value to float so we can multiply

df['Over_Value'] = df['Over_Value'].astype(float)

# Define a function to compute the odds based on the sign
def compute_odds(row, column):
    value = float(row[column + '_Value_Split'])
    odds = row[column + '_Odds']
    
    if odds.startswith('-'):
        return abs(value) / (abs(value) + 100)
    elif odds.startswith('+'):
        return 100 / (int(value) + 100)
    else:
        return None

# Apply the function to compute the odds for 'Over' and 'Under'
df['Over_Odds_Computed'] = df.apply(lambda row: compute_odds(row, 'Over'), axis=1)
df['Under_Odds_Computed'] = df.apply(lambda row: compute_odds(row, 'Under'), axis=1)
df['Final_Converted'] = (df['Over_Odds_Computed']+0.5)*df['Over_Value']
# Display the updated dataframe
df.head(25)
# Out:
#                  Team       Over      Under  Over_Value Over_Odds Under_Value  \
# 0           Air Force   8.5 +125   8.5 −150         8.5      +125         8.5
# 1               Akron   3.5 −120   3.5 −105         3.5      -120         3.5
# 2             Alabama  10.5 +135  10.5 −155        10.5      +135        10.5
# 3   Appalachian State   6.5 −110   6.5 −115         6.5      -110         6.5
# 4             Arizona     5 −120     5 +100         5.0      -120           5
# 5       Arizona State     5 +120     5 −140         5.0      +120           5
# 6            Arkansas     7 +100     7 −120         7.0      +100           7
# 7      Arkansas State   4.5 −145   4.5 +120         4.5      -145         4.5
# 8                Army     6 +105     6 −130         6.0      +105           6
# 9              Auburn   6.5 −135   6.5 +115         6.5      -135         6.5
# 10         Ball State   4.5 −120   4.5 −105         4.5      -120         4.5
# 11             Baylor   7.5 +135   7.5 −160         7.5      +135         7.5
# 12        Boise State     9 +140     9 −170         9.0      +140           9
# 13     Boston College   5.5 −120   5.5 +100         5.5      -120         5.5
# 14      Bowling Green     5 +105     5 −130         5.0      +105           5
# 15                BYU   5.5 −120   5.5 +100         5.5      -120         5.5
# 16         California     5 +110     5 −130         5.0      +110           5
# 17   Central Michigan   5.5 −110   5.5 −115         5.5      -110         5.5
# 18          Charlotte   2.5 −120   2.5 −105         2.5      -120         2.5
# 19         Cincinnati   5.5 +110   5.5 −130         5.5      +110         5.5
# 20            Clemson   9.5 −140   9.5 +120         9.5      -140         9.5
# 21   Coastal Carolina     8 −120     8 −105         8.0      -120           8
# 22           Colorado     3 −105     3 −115         3.0      -105           3
# 23     Colorado State   4.5 −115   4.5 −110         4.5      -115         4.5
# 24               Duke   6.5 +115   6.5 −135         6.5      +115         6.5
#
#    Under_Odds  Over_Value_Split Over_Sign  Under_Value_Split Under_Sign  \
# 0        -150             125.0         +              150.0          -
# 1        -105             120.0         -              105.0          -
# 2        -155             135.0         +              155.0          -
# 3        -115             110.0         -              115.0          -
# 4        +100             120.0         -              100.0          +
# 5        -140             120.0         +              140.0          -
# 6        -120             100.0         +              120.0          -
# 7        +120             145.0         -              120.0          +
# 8        -130             105.0         +              130.0          -
# 9        +115             135.0         -              115.0          +
# 10       -105             120.0         -              105.0          -
# 11       -160             135.0         +              160.0          -
# 12       -170             140.0         +              170.0          -
# 13       +100             120.0         -              100.0          +
# 14       -130             105.0         +              130.0          -
# 15       +100             120.0         -              100.0          +
# 16       -130             110.0         +              130.0          -
# 17       -115             110.0         -              115.0          -
# 18       -105             120.0         -              105.0          -
# 19       -130             110.0         +              130.0          -
# 20       +120             140.0         -              120.0          +
# 21       -105             120.0         -              105.0          -
# 22       -115             105.0         -              115.0          -
# 23       -110             115.0         -              110.0          -
# 24       -135             115.0         +              135.0          -
#
#     Over_Odds_Computed  Under_Odds_Computed  Final_Converted
# 0             0.444444             0.600000         8.027778
# 1             0.545455             0.512195         3.659091
# 2             0.425532             0.607843         9.718085
# 3             0.523810             0.534884         6.654762
# 4             0.545455             0.500000         5.227273
# 5             0.454545             0.583333         4.772727
# 6             0.500000             0.545455         7.000000
# 7             0.591837             0.454545         4.913265
# 8             0.487805             0.565217         5.926829
# 9             0.574468             0.465116         6.984043
# 10            0.545455             0.512195         4.704545
# 11            0.425532             0.615385         6.941489
# 12            0.416667             0.629630         8.250000
# 13            0.545455             0.500000         5.750000
# 14            0.487805             0.565217         4.939024
# 15            0.545455             0.500000         5.750000
# 16            0.476190             0.565217         4.880952
# 17            0.523810             0.534884         5.630952
# 18            0.545455             0.512195         2.613636
# 19            0.476190             0.565217         5.369048
# 20            0.583333             0.454545        10.291667
# 21            0.545455             0.512195         8.363636
# 22            0.512195             0.534884         3.036585
# 23            0.534884             0.523810         4.656977
# 24            0.465116             0.574468         6.273256

# %% [markdown]
# And everything looks good. I like to hang onto any of our separate columns to be able to do Quality Assurance testing on the separate columns as there's multiple steps to our calculations.

# %%
df.drop(['Under_Value', 'Under_Odds', 'Over_Odds_Computed', 'Under_Odds_Computed', 'Over_Value_Split',
         'Over_Sign', 'Under_Value_Split', 'Under_Sign','Over_Odds'], axis =1, inplace=True)

# %%
df.sort_values(by='Final_Converted', ascending=False, ignore_index=True).head(30)
# Out:
#                 Team       Over      Under  Over_Value  Final_Converted
# 0            Georgia  11.5 +130  11.5 −150        11.5        10.750000
# 1                USC   9.5 −165   9.5 +140         9.5        10.665094
# 2           Michigan  10.5 −105  10.5 −115        10.5        10.628049
# 3         Ohio State  10.5 −105  10.5 −115        10.5        10.628049
# 4            Clemson   9.5 −140   9.5 +120         9.5        10.291667
# 5      Florida State    10 −105    10 −115        10.0        10.121951
# 6         Penn State   9.5 −130   9.5 +110         9.5        10.119565
# 7           Oklahoma   9.5 −115   9.5 −105         9.5         9.831395
# 8     Oklahoma State   9.5 −115   9.5 −105         9.5         9.831395
# 9              Texas   9.5 −115   9.5 −105         9.5         9.831395
# 10           Alabama  10.5 +135  10.5 −155        10.5         9.718085
# 11            Oregon   9.5 +100   9.5 −120         9.5         9.500000
# 12               LSU   9.5 +110   9.5 −130         9.5         9.273810
# 13        Washington     9 −105     9 −115         9.0         9.109756
# 14            Tulane   9.5 +120   9.5 −145         9.5         9.068182
# 15    North Carolina   8.5 −125   8.5 +105         8.5         8.972222
# 16         Tennessee   9.5 +130   9.5 −150         9.5         8.880435
# 17        Notre Dame     9 +110     9 −130         9.0         8.785714
# 18           Liberty   9.5 +140   9.5 −165         9.5         8.708333
# 19              Troy     8 −140     8 +115         8.0         8.666667
# 20      Oregon State     8 −135     8 +115         8.0         8.595745
# 21         Wisconsin     9 +125     9 −145         9.0         8.500000
# 22  Coastal Carolina     8 −120     8 −105         8.0         8.363636
# 23      Kansas State   8.5 +110   8.5 −130         8.5         8.297619
# 24              UCLA   8.5 +110   8.5 −130         8.5         8.297619
# 25         Texas A&M   7.5 −150   7.5 +130         7.5         8.250000
# 26       Boise State     9 +140     9 −170         9.0         8.250000
# 27               SMU     8 −110     8 −115         8.0         8.190476
# 28              Iowa   7.5 −145   7.5 +125         7.5         8.188776
# 29     James Madison   7.5 −140   7.5 +115         7.5         8.125000

# %%
df.sort_values(by='Final_Converted', ascending=False, ignore_index=True).head(30).describe()
# Out:
#        Over_Value  Final_Converted
# count   30.000000        30.000000
# mean     9.116667         9.214688
# std      0.979825         0.873582
# min      7.500000         8.125000
# 25%      8.500000         8.397727
# 50%      9.500000         9.020202
# 75%      9.500000         9.831395
# max     11.500000        10.750000

# %%
# Save to a CSV for our future usage

df.to_csv('CFB_23_Win_Totals.csv')

# %% [markdown]
# # In Conclusion
#
# So in conclusion, we scraped some table data from DraftKings in order to manipulate that data to show which teams are projected to have the highest win totals with all things being equal. We had to separate the odds from the win total, and then use those odds to calculate the implied probabilty and added 50% to attempt to centralize the odds as much as possible. After that, we folded back in our win total to give us an apples to apples comparision of the data. Looks like after our conversion, our mean went up slightly and the std ticked down, showing that our centralizing process did smooth out some of the bumps affiliated with different odds for different win totals. This could also be from Georgia's win total going from above 2 standard deviations to "merely" 1.8 -- a modest improvement but an improvement nevertheless.
#
# This CSV will be available for download if anyone else wants a proper 'anchor point' for the NCAAF season. An example of this is if a team in the top 25, like North Carolina or Kansas State, starts off 1-2 and plays a team in the fourth week as a sizable favorite, you'll have better insight where that number came from.
#
# Also, keep in mind these odds will change as more money comes onto a specific side, the bookmakers will adjust their number to mitigate overleveraging a position. This could be informative itself as the more the odds change the more action that position is taking (assuming no new information regarding the team). Whether that's the public reading a news article about how Caleb Williams will dominate this season, or seasoned professionals moving markets, the odds movement is important to keep in mind when wagering this upcoming season.
#
# Happy handicapping -- September cannot come soon enough.

# %% [markdown]
# # PS
#
# For those that stuck around, we need to come back around and see which teams we left off the ticket. Here, we can double check our results against another betting site, reviewjournal, and do a join to see which teams were excluded from DraftKings totals. The two tables could be the same which would tell me that there's a reason like an injury or coaching issue that the book would wait out prior to posting a number.

# %%
url = 'https://www.reviewjournal.com/sports/betting/college-football-regular-season-win-totals-full-list-of-133-teams-2785339/'

page = requests.get(url)
  
soup = BeautifulSoup(page.text, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
#
# <html class="nojs" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>NCAA College football regular season win totals — FULL LIST of 133 teams | Las Vegas Review-Journal</title>
# <meta content="max-image-preview:large" name="robots">
# <link href="//cdnjs.cloudflare.com" rel="dns-prefetch">
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//projects.reviewjournal.com" rel="dns-prefetch"/>
# <link href="//stats.wp.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//v0.wordpress.com" rel="dns-prefetch"/>
# <link href="https://www.reviewjournal.com/feed/" rel="alternate" title="Las Vegas Review-Journal » Feed" type="application/rss+xml"/>
# <link href="https://www.reviewjournal.com/comments/feed/" rel="alternate" title="Las Vegas Review-Journal » Comments Feed" type="application/rss+xml"/>
# <link crossorigin="anonymous" href="https://fonts.googleapis.com/css?family=Merriweather%3A400%2C700%2C900%7CRaleway%3A400%2C700%2C900&amp;display=swap&amp;ver=20230626.1" id="rjth-fonts-css" media="all" rel="stylesheet"/>
# <link href="https://www.reviewjournal.com/_static/??-eJyNjksOgzAMRC/UxIAKoYuqZwkmFWnzQbErxO0JQiyiSlW3M2+eDcssMAY2gYEn4w1BevHUVPUNnB2STis8cy/0Yih6I65SyQqQqIilt0Hm8AI/fMSr+4/c9XMkLmAb0H3GjO3taIlhcBHf4nzzW18s0Gkii+K4dXIPf6+7XjV926puAyWWYEw=" id="all-css-2" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-block-library-inline-css">
# .has-text-align-justify{text-align:justify;}
# </style>
# <style id="global-styles-inline-css">
# body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}body .is-layout-flow > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-flow > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-flow > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-constrained > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-constrained > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > :where(:not(.alignleft):not(. ...
# .wp-block-navigation a:where(:not(.wp-element-button)){color: inherit;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}
# .wp-block-pullquote{font-size: 1.5em;line-height: 1.6;}
# </style>
# <link href="//cdnjs.cloudflare.com/ajax/libs/select2/4.0.13/css/select2.min.css?ver=6.2.2" id="select2-css" media="all" rel="stylesheet"/>
# <link href="https://www.reviewjournal.com/wp-content/plugins/rj/library/xslide/_css/xslide.min.css?m=1687824413g" id="all-css-6" media="all" rel="stylesheet" type="text/css"/>
# <link href="//cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.css?ver=6.2.2" id="jquery-ui-css" media="all" rel="stylesheet"/>
# <link href="https://www.reviewjournal.com/_static/??/wp-content/plugins/rj/public/css/rjautos.min.css,/wp-content/mu-plugins/jetpack-12.2/css/jetpack.css?m=1687933509" id="all-css-8" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://www.reviewjournal.com/_static/??-eJyNy0ESgjAMheELWQLMQGHheBYtGUmGppoEHW5vFxzA1Vu874fvK6QijuLgK2Y0UPa1b7sZ2IDqo4bJqUgoD0P9oDaZpGG7QG1J0rYvtaqY3zvqcc5fKGR66t3xxLd87cYp9tMwxMg/kfA4Zg==" type="text/javascript"></script><script id="rjth-layout-js" src="https://www.reviewjournal.com/wp-content/themes/rjth2019/js/layout.min.js?ver=20230626.1"></script>
# <script id="rjth-layout-js-after">
# 		jQuery( document ).ready(function() {
# 			if (typeof dataLayer !== "undefined") {
# 				dataLayer.push({"event": "jQueryIsReady", "jquery_is_ready": true});
# 			}
# 		});
# </script>
# <script src="https://www.reviewjournal.com/_static/??/wp-content/plugins/rj/public/js/rj-public.min.js,/wp-content/plugins/rj/library/xdrag.min.js?m=1677529122j" type="text/javascript"></script><script id="select2-js" src="//cdnjs.cloudflare.com/ajax/libs/select2/4.0.13/js/select2.min.js?ver=6.2.2"></script>
# <script id="rj-autos-js-js-extra">
# var ajax_params_autos = {"ajax_url":"https:\/\/www.reviewjournal.com\/wp-admin\/admin-ajax.php","ajax_nonce_autos_get_data":"6e817593ba","google_api_key":"AIzaSyDMcDUzs0wcz1AkNXgewafVYI8PODGC_cw"};
# </script>
# <script id="rjth-post-js-extra">
# var js_data = {"google_api_key":"AIzaSyDMcDUzs0wcz1AkNXgewafVYI8PODGC_cw","gallery_auto_full_screen":"1","gallery_ads_slide_th":"5","gallery_ads_slide":"ad-image_feed_1","gallery_ads_under":"ad-image_feed_2","gallery_ads_left":"","gallery_ads_right":"","gallery_ads_under_uid":"","gallery_ads_right_uid":"","gallery_related_story":[{"title":"Daniel Negreanu to face former rival on \u2018High Stakes Duel 4\u2019","img":"https:\/\/www.reviewjournal.com\/wp-content\/uploads\/2023\/06\/17938930_web1_BET-WSOP-053023-es_009.jpg?w=360&h=240&crop=1","link":"https:\/\/www.reviewjournal.com\/sports\/poker\/daniel-negreanu-to-face-former-rival-on-high-stakes-duel-4-2800866\/"},{"title":"Here\u2019s every defensive, special teams TD scored in Super Bowl","img":"https:\/\/www.reviewjournal.com\/wp-content\/uploads\/2023\/06\/17911361_web1_APTOPIX-Super-Bowl-Football.jpg?w=360&h=240&crop=1","link":"https:\/\/www.reviewjournal.com\/sports\/betting\/heres-every-defensive-special-teams-td-scored-in-super-bowl-2800234\/"},{"title":"Legendary poker pro falls short of 8th career WSOP bracelet","img":"https:\/\/www.reviewjournal.com\/wp-content\/uploads\/2023\/06\/17931835_web1_WEB-Baxter-062623.jpg?w=360&h=240&crop=1","link":"https:\/\/www.reviewjournal.com\/sports\/poker\/legendary-poker-pro-falls-short-of-8th-career-wsop-bracelet-2800036\/"},{"title":"What sports bettors can expect to get out of Bet Bash at Circa","img":"https:\/\/www.reviewjournal.com\/wp-content\/uploads\/2023\/06\/17931675_web1_BET-SUPERBOWL1A-JAN31-22-bh-002.jpg?w=360&h=240&crop=1","link":"https:\/\/www.reviewjournal.com\/sports\/betting\/what-sports-bettors-can-expect-to-get-out-of-bet-bash-at-circa-2800023\/"}],"gallery_related_text":"More Stories"};
# </script>
# <script src="https://www.reviewjournal.com/_static/??-eJyNi8sKgCAQAH+oXHpQXaJPCTWJXUzFVaq/j8Bjh24zMANnqLV3ybgEweYdHUMksKiijDdcbHEzsBIXFAc6QVzB9xeysqiBXpE5ef7dB8+pxMsxN8M0Tm3fNx09c+I7PA==" type="text/javascript"></script><script async="async" id="gpt-js" src="//securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script id="gpt-js-after">
# window.googletag = window.googletag || {cmd: []};
# </script>
# <script async="async" id="prebidjs-js" src="https://projects.reviewjournal.com/header-bidding/prebid-7.43.0.js"></script>
# <script id="ad-tags-js-extra">
# var rj_ads_info = {"ad_unit_path_prefix":"\/104590658\/RJ","post_id":"2785339","article":"1","level":"2","parent":["sports"],"child":["betting"],"section":["sports"],"env":"production","enable_listener":"1","enable_refresh":"1","enable_lazyload":"1","use_safeframe":"0","biddersConfig":{"debug":false,"checkMobile":false,"bidCpmMin":0.15,"bidCpmAdjustment":1.5,"allowBidCpmAdjustment":false,"inViewRefresh":23,"outOfViewRefresh":300,"allowExternalRefresh":false,"enableSingleRequest":false,"fetchMarginPercent":200,"renderMarginPercent":100,"lazyAdsRootMargin":"400px 0px","filterConfig":{"advertisers":[4648477914,4648491038,4649535526,4650825824,4650867746,4651460818,4652095883,4652538632,4652551093,4652553267,4652566714,4652635160,4652667302,4653184021,4654050192,4654100061,4654136561,4654200903,4654596237,4654774015,4655271975,4655365409,4656241848,4656764596,4658262885,4659143686,4659173910,4659825244,4660422653,4660967971,4662801818,4662880219,4664349511,4664896471,4666525405,4666652572,4667118218,4667132872,4667471901,4667550365,4667643977,4667741731,4668083470,4670066634,4670159650,4670511051,4670586388,4675309812,4675309812,4675754364,4676229078,4679810811,4681132765,4681204201,4681260949,4684209495,4634127795,4634143386,4634292452,4634397968,4634813233,4634818051,4634854504,4634924863,4634940931,4634970364,4635770289,4636262544,4636315837,4636333110,4636442819,4636946284,4637038729,4637068319,4637078105,4637080283,4637505012,4637597402,4637634206,4637661814,4637673736,4637686508,4637707893,4637819501,4637829311,4637856653,4638213802,4638238303,4638267532,4638269685,4638396401,4638439103,4638916762,4639691717,4639811462,4640151087,4640168619,4640254031,4640287181,4641316005,4641503705,4642869324,4642974414,4643073836,4643636323,4644140554,4644804702,4645409979,4645476207,4647483764,4647882936,4648009387,4626877891,4626925880,4626928762,4626942362,4626952751,4627097208,4627128429,4627188225,4627344931,4627370839,4627373692,4627466059,4627471375,4627818944,4627845808,4628352874,4628373019,4628381443,4628922711,4628976705,4629181196,4629353994,4629382701,4629724441,4630100845,4630109422,4630170865,4630195330,4630358103,4630537612,4630573105,4630575555,4630580771,4630593080,4630661996,4630812896,4630903821,4630970283,4631060609,4631127793,4631136698,4631565994,4631619049,4632500126,4632537308,4632750369,4632766752,4632820449,4633103958,4633401524,4633406111,4633468924,4633565517,4633758845,4633798244,4633840502,4589457974,4609211681,4607271756,4609211681,4609816925,4610337497,4610740279,4610762560,4611556712,4611776524,4612491990,4612907987,4612943955,4613031756,4613679316,4615047089,4615282048,4615709991,4616015687,4616092310,4616159649,4618041245,4618181496,4618201398,4618318752,4618518848,4618525367,4618723914,4619234044,4619276311,4619299912,4619363506,4619377832,4619444531,4619494514,4619783023,4619821171,4619932267,4620714203,4620901614,4621257256,4621979918,4621987916,4622087986,4622449822,4623005979,4623350114,4623436746,4623486954,4624442349,4624704841,4626193899,4626274938,4626645498,4626646473,4626689937,4589849749,4590947225,4592027178,4592336087,4592521392,4592578924,4593866622,4593936159,4594378257,4594424095,4594626419,4594743570,4595382397,4595497673,4595594840,4595620701,4595703090,4595771475,4595826376,4596064295,4597192760,4597848640,4597945410,4597945823,4597967641,4598186825,4598203334,4598203382,4598249435,4598254044,4598283781,4598534567,4598918041,4599339483,4599370932,4599698393,4600312241,4601569361,4601656922,4601994223,4602700050,4603064334,4603655226,4603804921,4604061353,4604175048,4604303251,4604524025,4604615223,4604990147,4605309997,4605404281,4605739161,4606491040,4587568286,4575130047,4575402713,4575421652,4575598272,4575645975,4576000799,4576024013,4576068467,4576072517,4576145722,4576237642,4576513610,4576589953,4576598869,4577426838,4577869565,4577907266,4577993019,4578310226,4578358922,4578498675,4578622774,4578632086,4578988315,4579132296,4579398629,4579442613,4579454586,4579495190,45795244 ...
# </script>
# <script src="https://www.reviewjournal.com/_static/??-eJxtjEsKgCAUAC/U86FQ0iI6SmhGKP7oKVGnj6CgRbuZxQzuGeYUyxILZl9XGwk3h7lqb2d0hMpAUStN2pqXIScqLNjIHDX4OwCvzgN8UuZ+fP3pxjDwTspW9FwIdwEV8C/e" type="text/javascript"></script><script id="mg2_loader_loader-js-extra">
# var MG2 = {"settings":{"environment":"prod","version":"review-journal","xCode":"","randomURLChoosing":false,"plugins":[{"name":"FP","required":true,"initOptions":{"version":"review-journal","environment":"prod"}},{"name":"DL","required":true,"initOptions":{"version":"review-journal","environment":"prod","flowModes":"InterestsRecommendations, EngageABExperiments","tagManager":"GTM","containerId":"GTM-5ZBPF7G","collectors":["connext"]}},{"name":"NXT","required":true,"initOptions":{"environment":"prod","siteCode":"LVJR","configCode":"LVJR","clientCode":"Review-Journal","debug":false,"silentmode":true,"attr":"","settingsKey":"","userAuthenticationTime":180,"authSettings":{"domain":"login.reviewjournal.com","client_id":"eY8tZV4dKrsDfhJrhDk5uSnhImrV781p","redirect_uri":"https:\/\/www.reviewjournal.com\/auth-callback\/"}}}],"appInsightsKey":"8241cbc2-50a5-47c4-b91f-462506490fad"}};
# </script>
# <script async="async" id="mg2_loader_loader-js" src="https://www.reviewjournal.com/wp-content/plugins/mg2-loader-wp/static/loader_prod.min.js?ver=1.6.1"></script>
# <script id="mg2_loader_loader-js-after">
# var MG2Loader = MG2Loader || {};
# (function( MG2, MG2Loader ) {
# 	if ( 'undefined' !== typeof MG2 && 'undefined' !== typeof MG2Loader && MG2Loader.init) {
# 		MG2Loader.init( MG2.settings );
# 	} else {
# 		// wait for script to load in case "async" attribute is used.
# 		var timerIdPoll = setInterval(function () {
# 			if ( 'undefined' !== typeof window.MG2 && 'undefined' !== typeof window.MG2Loader && window.MG2Loader.init) {
# 				clearInterval(timerIdPoll);
# 				window.MG2Loader.init( window.MG2.settings );
# 			}
# 		}, 500);
# 	}
# })( MG2, MG2Loader );
# </script>
# <link href="https://www.reviewjournal.com/wp-json/" rel="https://api.w.org/"/><link href="https://www.reviewjournal.com/wp-json/wp/v2/posts/2785339" rel="alternate" type="application/json"/><link href="https://www.reviewjournal.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.reviewjournal.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 6.2.2" name="generator">
# <link href="https://www.reviewjournal.com/sports/betting/college-football-regular-season-win-totals-full-list-of-133-teams-2785339/" rel="canonical"/>
# <link href="https://www.reviewjournal.com/?p=2785339" rel="shortlink"/>
# <link href="https://www.reviewjournal.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.reviewjournal.com%2Fsports%2Fbetting%2Fcollege-football-regular-season-win-totals-full-list-of-133-teams-2785339%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://www.reviewjournal.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.reviewjournal.com%2Fsports%2Fbetting%2Fcollege-football-regular-season-win-totals-full-list-of-133-teams-2785339%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <meta content="app-id=1145034891" name="apple-itunes-app"/>
# <!-- RJ Meta Tags -->
# <meta content="Defending national champion Georgia has the highest regular season win total at Caesars Sportsbook at 11 (over-160). Massachusetts has the lowest at 2 (o-130)." name="description"/>
# <meta content="post_id-2785339" name="rj:id"/>
# <meta content="post_id-2785339" name="vf:container_id"/>
# <!-- Open Graph Tags -->
# <meta content="Las Vegas Review-Journal" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="College football regular season win totals — FULL LIST of 133 teams" property="og:title"/>
# <meta content="https://www.reviewjournal.com/sports/betting/college-football-regular-season-win-totals-full-list-of-133-teams-2785339/" property="og:url"/>
# <meta content="Defending national champion Georgia has the highest regular season win total at Caesars Sportsbook at 11 (over-160). Massachusetts has the lowest at 2 (o-130)." property="og:description"/>
# <meta content="https://www.reviewjournal.com/wp-content/uploads/2023/05/17832006_web1_CFP-National-Championship-Football.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="800" property="og:image:height"/>
# <meta content="2023-05-29T17:34:31+00:00" property="article:published_time"/>
# <meta content="2023-05-29T17:34:36+00:00" property="article:modified_time"/>
# <!-- END Open Graph Tags -->
# <!-- Twitter Card Tags -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@reviewjournal" name="twitter:site"/>
# <meta content="College football regular season win totals — FULL LIST of 133 teams" name="twitter:title"/>
# <meta content="Defending national champion Georgia has the highest regular season win total at Caesars Sportsbook at 11 (over-160). Massachusetts has the lowest at 2 (o-130)." name="twitter:description"/>
# <meta content="https://www.reviewjournal.com/wp-content/uploads/2023/05/17832006_web1_CFP-National-Championship-Football.jpg" name="twitter:image"/>
# <!-- END Twitter Card Tags -->
# <!-- End RJ Meta Tags -->
# <!-- RJ Paywall Meta Tags -->
# <meta content="private" name="rj:paywall"/>
# <!-- End RJ Paywall Meta Tags -->
# <style type="text/css">
# 			/* If html does not have either class, do not show lazy loaded. */
# 			html:not( .rj-lazy-load-js-enabled ):not( .js ) .rj-lazy-load {
# 				display: none;
# 			}
# 		</style>
# <script>
#             document.documentElement.classList.add(
#                 'rj-lazy-load-js-enabled'
#             );
# 		</script>
# <style>img#wpstats{display:none}</style>
# <link href="https://www.reviewjournal.com/wp-content/themes/rjth2019/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://www.reviewjournal.com/wp-content/themes/rjth2019/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://www.reviewjournal.com/wp-content/themes/rjth2019/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="https://www.reviewjournal.com/wp-content/themes/rjth2019/favicons/favicon.ico" rel="shortcut icon"/><link color="#c21c2b" href="https://www.reviewjournal.com/wp-content/themes/rjth2019/favicons/safari-pinned-tab.svg" rel="mask-icon"><link href="https://www.reviewjournal.com/wp-content/themes/rjth2019/favicons/manifest.json" rel="manifest"/><meta content="https://www.reviewjournal.com/wp-content/themes/rjth2019/favicons/browserconfig.xml" name="msapplication-config"/><meta content="#ffffff" name="theme-color"/><link href="https://www.reviewjournal.com/sports/betting/college-football-regular-season-win-totals-full-list-of-133-teams-2785339/amp/" rel="amphtml"/> <style id="wp-custom-css" type="text/css">
# 			/* temp fix why jetpack blur the form */
# .wp-block-jetpack-contact-form-container {filter:none !important;}
#
# /* temp fix remove this after update post.css */
# .rj-story-full .rj-gallery .xmedia.stn > div:first-child {
#     margin-top: 0px;
# }
#
#
# /* show ear-ads on scroll */
# @media (min-width: 1100px) {
#     #menu-top.fixed .ear-ads {
#         display: block;
#         padding-bottom: 0;
#         margin-left: 150px;
#     }
#     #menu-top.fixed .ear-ads.right {
#         margin: 0 150px 0 0;
#     }
# }
#
# #weather-widget .wicon {height:30px; }
#
# fuel-video .close-button {z-index:9999;}
#
# /* hide page title */
# body.category-despair .wrap-page-header,
# body.category-the-water-question .wrap-page-header {display:none;}
#
# /* Foleon content */
# .tag-foleon.rj-sponsored.rj-story.rj-story-thumb-list {
#     position: relative;
# 	background-color: #000;
# }
# .tag-foleon.rj-sponsored.rj-story.rj-story-thumb-list a {
# 	color: #fff;
# }
# .tag-foleon.rj-sponsored.rj-story.rj-story-thumb-list .field-excerpt {
#     color: #fff;
# }
# /* End Foleon content */
#
# /* begin tribune subhead */
# article.tag-tribune h3 {
# 	font-size: 1.6em;
#     font-style: normal;
#     font-family: Raleway, "Helvetica Neue", Helvetica, Arial, sans-serif;
#     font-weight: 900;
#     margin: 5px 0;
#     display: block;
# }
# @media (min-width: 768px) {
#     article.tag-tribune h3 {
#         margin: 15px 0;
#     }
# }
# /* end tribune subhead */
#
# /* begin attachement */
# body.attachment-template-default #main {
# 	padding: 0 20px;
# }
# body.attachment-template-default .nav-previous::before {
# 	content: 'Read the full article: ';
# }
# body.attachment-template-default .nav-previous a {
# 	color: #337ab7;
# 	text-decoration: underline;
# }
# body.attachment-template-default .nav-links {
# 	font-weight: bold;
# 	border-bottom: solid 4px #000;
# 	padding-bottom: 25px;
# 	margin-bottom: 25px;
# }
# @media (min-width: 768px) {
# 	body.attachment-template-default #main {
# 		padding: 0;
# 	}
# }
# /* end attachement */
#
#
# article p img {display:block; max-width:100%; height:auto}
# .tag-penny-hoarder .entry-content figure,
# .tag-penny-hoarder .entry-content figure {width: 100% !important;}
#
#
# /* begin change latest text */
# body.tag-bishop-gorman-gael-force .latest-news .rj-widget-title {
#   text-indent: -9999px;
#   line-height: 0;
# }
# body.tag-bishop-gorman-gael-force .latest-news .rj-widget-title::after {
#   content: "More Gael Force";
#   text-indent: 0;
#   display: block;
#   line-height: initial;
# }
# /* end change latest text */
#
# .tax-rj_author .rj-category-description {
#     font-family: "Merriweather",serif;
#     line-height: 1.4;
#     margin-bottom: 10px;
# }
# .tax-rj_author .rj-category-description p {
#     margin-bottom: 10px;
#  }
#
# .triptic img {
#     width: 100%;
# }
# @media (min-width: 768px) {
#     .triptic img {width: 32.8%}
#     .side-by-side .wp-caption.regular {width: calc( 50% - 10px );}
# }
#
# body.archive.tag-14413 .rj-category-image,
# body.archive.tag-12192 .rj-category-image,
# body.archive.tag-14338 .rj-category-image { display: none; }
# @media (min-width: 1120px) {
#     .rj-story-full {
#         padding: 0px;
#     }
# }
# @media (min-width: 1100px) {
#     .rj-story-full.has-right-sidebar {
#         padding-left: 50px;
#     }
# }
# @media (min-width: 1330px) {
#     .rj-story-full.has-right-sidebar {
#         padding-left: 0;
#     }
# }
# @media (max-width: 767px) {
# .rj-gutter-phone {
#     padding-left: 20px;
#     padding-right: 20px;
# }
# }
#
# .max-width-1200 {
#         max-width: 1200px;
#         margin: 0 auto;
# }
# @media (min-width: 768px) {
#    .padding-20-768-1240 {
#            padding: 0 20px;
#    }
# }
# @media (min-width: 1240px) {
#    .padding-20-768-1240 {
#            padding: 0;
#    }
# }
# .rj-story-sponsored-full figure.wp-caption {
#   width: auto !important;
# }
# .rj-story-sponsored-full img.aligncenter {
#   width: 100%;
#     height: auto;
# }
# .rj-story-sponsored-full figure.wp-caption.lightbox {
#     width: 100% !important;
# }
#
# .menu-item.rj-red > a {color:#d82121; font-weight:bold;}
#
# .jwplayer.jw-flag-fullscreen {z-index: 1100 !important;}
#
# /* related story */
# .rs-container {
#     background-color: #eee;
#     padding: 10px 20px;
# }
# @media (max-width: 900px) {
#     #menu-main #primary-menu .menu-item a {
#         font-size: 12px;
#     }
# }
# @media (min-width: 768px) {
#     .rj-widget.top-news-1-4 .field-col.left .rj-story {
#         border-bottom: 1px solid #ccc;
#     }
# }
# body .Mg2-connext[data-display-type] {overflow-x:hidden !important;}
#
# .hide {display: none !important;}
#
# /* seo relate link bottom */
# #rj-footer .be-ix-link-block .be-related-link-container .be-label {
#     font-size: 11px;
#     color: #000;
#       font-weight: normal;
# }
# #rj-footer .be-ix-link-block .be-related-link-container .be-list {
#     font-size: 11px;
# }
#
# .teads-inboard, .teads-inread, .teads-inboard > div, .teads-inread > div, .teads-player {
#     z-index: 1;
# }
#
# .centerhead h2 {
#     font-weight: 900;
#     font-size: 3em;
# }
#
# .sbs-left { margin: 20px 7px 20px 0; float: none; display: inline-block; vertical-align: top; }
# .sbs-right { margin: 20px 0px 20px 7px; float: none; display: inline-block; vertical-align: top; }
#
# /*
# .rj-story-full .entry-content > p{
#     overflow-x: visible;
# }
# */
# @media (min-width: 768px) {
# .rj-story-full .entry-content .xl.wp-caption .wp-caption-text { padding: 5px 15px; }
# }
#
# .contact-submit .pushbutton-wide {
#     background-color: #d82121;
#     border: 1px solid #d82121;
# }
#
# .rj-newsletter-signup-center, .rj-newsletter-signup-center .rj-widget-title { text-align: center !important; }
#
# /*Sports Refers*/
# .rj-sports-refers {
#     font-family: "Merriweather", serif;
#     font-size: 19px;
#     font-weight: 500;
#     font-style: normal;
#     font-stretch: normal;
#     line-height: 32px;
#     letter-spacing: normal;
#     color: #000;
#     margin: 15px 12px 0 12px;
#     overflow-x: auto;
# }
# @media (min-width: 768px) {
#     .rj-sports-refers {
#         margin: 15px 0 0;
#     }
# }
# /*Float helpers*/
# @media (max-width: 768px) {
#     .rj-fr-mobile {float: right;}
#     .rj-fl-mobile {float: left;}
# }
# @media (min-width: 768px) and (max-width: 1100px) {
#     .rj-fr-tablet {float: right;}
#     .rj-fl-tablet {float: left;}
# }
# @media (min-width: 1100px) {
#     .rj-fr-desktop {float: right;}
#     .rj-fl-desktop {float: left;}
# }
# /*END-Float helpers*/
# /*AppRequest*/
# body.rj-is-app-request .hide-from-rjapp, body.rj-is-app-request .hide-from-vnapp, .hide-from-website {display: none !important}
# body.rj-is-app-request input.connext-actflow-cep-login__input {font-size:16px !important;}
# /*END-AppRequest*/
# /*SubNavMobile*/
# @media (max-width: 599px) {
#     .side-rail-nav .dropdown li.active > a, .side-rail-nav .dropdown a:hover, .side-rail-nav .dropdown a:focus {
#             background-color: #626366;
#     }
# }
# /*END-SubNavMobile*/
# #menu-top .subs-menu .subs-elem.show { display: inline-block !important;}
# /*RJVideo*/
# article.rj_video .entry-meta.single-date time.entry-date.published {display: inline !important;}
# article.rj_video .entry-meta.single-date time.updated {display: none;}
# /*END-RJVideo*/
# /*Ads*/
# .square-ad {
#     width: 336px;
#     height: 280px;
#     margin: 0 auto;
#     display: flex !important;
#     justify-content: center;
#     align-items: center;
# }
# /*END-Ads*/
# /*STN fix*/
# #rj-region-top.rj-region.rj-left-side {z-index: 2}
# /*END-STN fix*/		</style>
# <!-- BEGIN metadata tag -->
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"NewsArticle","publisher":{"@type":"Organization","name":"Las Vegas Review-Journal","logo":{"@type":"ImageObject","url":"https:\/\/www.reviewjournal.com\/wp-content\/uploads\/2020\/07\/rj_logo_black2.png?w=400","width":400,"height":59}},"mainEntityOfPage":"https:\/\/www.reviewjournal.com\/post\/2785339","image":["https:\/\/www.reviewjournal.com\/wp-content\/uploads\/2023\/05\/17832006_web1_CFP-National-Championship-Football.jpg?w=700"],"thumbnailUrl":"https:\/\/www.reviewjournal.com\/wp-content\/uploads\/2023\/05\/17832006_web1_CFP-National-Championship-Football.jpg?w=150&h=100&crop=1","headline":"College football regular season win totals \u2014 FULL LIST of 133 teams","url":"https:\/\/www.reviewjournal.com\/post\/2785339","dateCreated":"2023-05-29T17:34:31Z","datePublished":"2023-05-29T17:34:31Z","dateModified":"2023-05-29T17:34:36Z","creator":[{"@type":"Person","name":"Todd Dewey","url":"https:\/\/www.reviewjournal.com\/staff\/todd-dewey\/"}],"author":[{"@type":"Person","name":"Todd Dewey","url":"https:\/\/www.reviewjournal.com\/staff\/todd-dewey\/"}],"keywords":"Betting, Football, Sports, UNLV, UNLV Football, mc-sports, Todd Dewey","description":"<p>Defending national champion Georgia has the highest regular season win total at Caesars Sportsbook at 11 (over-160). Massachusetts has the lowest at 2 (o-130).<\/p>","articleSection":"Betting"}</script>
# <!-- END metadata tag -->
# </link></meta></link></meta></head>
# <body class="post-template-default single single-post postid-2785339 single-format-standard wp-custom-logo rj-main-category--betting rj-main-category-id--43">
# <script type="text/javascript">
# 			dataLayer = [{"rj_page_type":"story","node_type":"article","vdo_num":0,"img_num":2,"content_source":"Local","metrics":{"pageType":"article","mediaType":"article","articleId":2785339,"articlePublishTime":"2023-05-29T17:34:31+00:00","articleUpdateTime":"2023-05-29T17:34:36+00:00","articleType":"post","author":["Todd Dewey"],"articleSource":"Local","section":"Betting","categories":["Betting","Football","Sports","UNLV","UNLV Football"],"hierarchy":"Sports | Betting","hl-category":"Sports"}}];
# 			function gtag() {
# 				if (!arguments || 'event' !== arguments[0] || !arguments[2] || !arguments[2].event_category || !arguments[2].event_action || !arguments[2].event_label) {
# 					return;
# 				}
#
# 				var data = arguments[2];
# 				dataLayer.push({
# 					'event': 'GAEvent',
# 					'category': data.event_category,
# 					'action': data.event_action,
# 					'label': data.event_label
# 				});
# 			}
# 		</script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WJQX3C" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 				new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 				j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 				'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 			})(window,document,'script','dataLayer',"GTM-WJQX3C");</script>
# <!-- End Google Tag Manager -->
# <header id="header-main">
# <!-- #menu-top -->
# <div class="rj-container menu-top-container">
# <div id="menu-top">
# <div class="menu-top-helper">
# <div class="menu-bars" id="button-nav-toggle">
# <i aria-hidden="true" class="fa fa-bars"></i>
# </div>
# <div id="rjth-region-header">
# <div class="rj-widget-num-1 rj-widget-first rj-widget-odd rj-widget rj_widget_text" id="rj_widget_text-573"> <div class="textwidget"><script>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# var RJAdTargetingManager = RJAdTargetingManager || {};
# RJAdTargetingManager.App = (function () {
#     var _init = function (googletag) {
#         _targetTagPage(googletag);
#         _initArticleTag(googletag);
#     };
#     var _targetTagPage = function() {
#         var bodyElem = document.querySelector('body.archive.tag');
#         if (bodyElem) {
#             _targetTagFromElem(googletag, bodyElem);
#         }
#     };
#     var _initArticleTag = function(googletag) {
#         if (document.querySelector('body.single-post')) {
#             googletag.cmd.push(function() {
#                 RJAdTargetingManager.App.InitArticleAdTag(googletag);
#             });
#         }
#     };
#     var _targetArticleTag = function(googletag) {
#         _targetTagFromElem(googletag, document.querySelector('article.rj-story-full'));
#     };
#     var _targetTagFromElem = function(googletag, elem) {
#         var tagList = _extractTags(elem);
#         if (tagList.length > 0) {
#             googletag.cmd.push(function() {
#                 googletag.pubads().setTargeting('tag', tagList);
#             });
#         }
#     };
#     var _extractTags = function(elem) {
#         var t, tagList = [];
#         if (elem) {
#             var classList = elem.classList;
#             classList.forEach(function(item, index) {
#                 if (item.startsWith('tag-')) {
#                     t = item.substr(4);
#                     if (t) {
#                         if (t !== 'rj-has-vdo' && !t.startsWith('mc-')) {
#                             tagList.push(t);
#                         }
#                     }
#                 }
#             });
#         }
#         return tagList;
#     };
#     return {
#         Init: _init,
#         InitArticleAdTag: _targetArticleTag,
#     };
# })();
# RJAdTargetingManager.App.Init(googletag);
# </script></div>
# </div><div class="rj-widget-num-2 rj-widget-even rj-widget rj_widget_text" id="rj_widget_text-351"> <div class="textwidget"><div class="ear-ads left">
# <div data-match-media="(min-width: 1100px)" id="ad-ear_left"></div>
# </div></div>
# </div><div class="rj-widget-num-3 rj-widget-odd top-logo-container rj-widget rj_widget_text" id="rj_widget_text-353"> <div class="textwidget"><div class="rj-logo">
# <a href="/" itemprop="url" rel="home" title="Las Vegas News"><img alt="Las Vegas News" class="rj-lazy-load lazy-image" data-lazy-src="https://www.reviewjournal.com/wp-content/uploads/2020/07/rj_logo_black2.png?w=400&amp;is-pending-load=1" height="59" src="https://www.reviewjournal.com/wp-content/uploads/2020/07/rj_logo_black2.png?w=400" srcset="..." width="400"/><noscript><img alt="Las Vegas News" height="59" src="https://www.reviewjournal.com/wp-content/uploads/2020/07/rj_logo_black2.png?w=400" width="400"/></noscript></a>
# </div>
# <div class="rj-skyline">
# <a href="/" title="Las Vegas News">
# <img alt="Las Vegas News" class="rj-lazy-load lazy-image" data-lazy-src="https://www.reviewjournal.com/wp-content/uploads/2021/09/skyline_w_logo_3.jpg?is-pending-load=1" height="92" src="https://www.reviewjournal.com/wp-content/uploads/2021/09/skyline_w_logo_3.jpg" srcset="..." width="410"/><noscript><img alt="Las Vegas News" height="92" src="https://www.reviewjournal.com/wp-content/uploads/2021/09/skyline_w_logo_3.jpg" width="410"/></noscript>
# </a>
# </div></div>
# </div><div class="rj-widget-num-4 rj-widget-even rj-widget rj_widget_text" id="rj_widget_text-354"> <div class="textwidget"><div class="ear-ads right">
# <div data-match-media="(min-width: 1100px)" id="ad-ear_right"></div>
# </div></div>
# </div><div class="rj-widget-num-5 rj-widget-last rj-widget-odd subs-menu-container rj-widget rj_widget_text" id="rj_widget_text-355"> <div class="textwidget"><a href="https://espanol.reviewjournal.com/?utm_campaign=RJ_Cross_Traffic&amp;utm_source=Main_Nav_Link&amp;utm_medium=NavLink" id="btn-ext-site" target="_blank"><span style="color:#000;">RJ</span>ESPAÑOL</a>
# <a class="btn-sub-eedition" href="https://digital.olivesoftware.com/olive/ODN/ReviewJournal/Default.aspx?utm_campaign=eEdition&amp;utm_source=lvrj&amp;utm_medium=header_eEdition" rel="nofollow" target="_blank">VIEW E-EDITION</a>
# <div class="subs-menu">
# <a class="subs-elem bg-red subs-now rj-paywall-subscribe" href="https://checkout.reviewjournal.com/def2?g2i_source=lvrj&amp;g2i_medium=button&amp;g2i_campaign=default&amp;g2i_or_p=default" id="mg2-subscribe-link" target="_blank">SUBSCRIBE</a>
# <div class="subs-popup">
# <div class="subs-traiangle"></div>
# <div class="info-box">
# <div class="field-title">Support local journalism.</div>
# <div class="field-link"><a href="https://checkout.reviewjournal.com/def2?g2i_source=lvrj&amp;g2i_medium=button&amp;g2i_campaign=default&amp;g2i_or_p=default" target="_blank">Only 99¢ / month</a></div>
# </div>
# </div>
# <a class="subs-elem bg-red" href="https://account.reviewjournal.com/" id="mg2-manage-account-link" target="_blank">MANAGE</a>
# <a class="subs-elem" data-mg2-action="activation" href="#" id="mg2-activate-link">ACTIVATE</a>
# <a class="subs-elem subs-sign-in rj-paywall-signin" data-mg2-action="activation" href="#" id="mg2-login-link" role="button">SIGN IN</a>
# <a class="subs-elem" data-mg2-action="logout" href="#" id="mg2-logout-link" role="button">SIGN OUT</a>
# </div>
# <script>
# (function ($) {
# //$(document).ready(function (e) {
#     $('#btn-ext-site').appendTo('.menu-top-helper');
# //});
# })(jQuery);
# </script>
# <style>
# #menu-top {
#     z-index: 1036;
#     overflow: visible;
# }
# #menu-top .subs-menu {
#     bottom: 5px;
# }
# #menu-top .subs-menu .subs-elem {
#     margin-left: 6px
# }
# #btn-ext-site {display: none;}
# .btn-sub-eedition {display: none;}
# @media (min-width: 768px) {
#     #menu-top .subs-menu {
#         bottom: 8px;
#     }
#     #btn-ext-site {
#         display: inline-block;
#         color: #d82121;
#         text-decoration: none;
#         font-size: 16px;
#         font-weight: 900;
#         cursor: pointer;
#         position: absolute;
#         left: 40px;
#         bottom: 20px;
#     }
#     a.btn-sub-eedition {
#         display: inline-block;
#         padding: 3px 5px;
#         border-radius: 5px;
#         color: #fff;
#         background-color: #d82121;
#         text-decoration: none;
#         font-size: 12px;
#         font-weight: 700;
#         cursor: pointer;
#         white-space: nowrap;
#         position: absolute;
#         right: 10px;
#         bottom: 33px;
#     }
# }
#
# .subs-menu .subs-popup {
#     display: none;
#     position: absolute;
#     right: 0;
#     width: 235px;
# }
# .subs-menu #mg2-subscribe-link:hover + .subs-popup {
#     display: block;
# }
# .subs-popup:hover {
#      display: block;
# }
# .subs-traiangle {
#     width: 0;
#     height: 0;
#     border-left: 10px solid transparent;
#     border-right: 10px solid transparent;
#     border-bottom: 10px solid #000;
#     position: relative;
#     top: 1px;
#     left: 190px;
# }
# .subs-traiangle:before {
#     content: '';
#     display: block;
#     position: absolute;
#     left: -8px;
#     top: 2px;
#     width: 0;
#     height: 0;
#     border-left: 8px solid transparent;
#     border-right: 8px solid transparent;
#     border-bottom: 8px solid #fff;
# }
# @media (min-width: 768px) {
#     .subs-traiangle {
#         left: 130px;
#     }
# }
# .subs-popup .info-box {
#     padding: 10px 20px;
#     font-size: 14px;
#     background-color: #fff;
#     border: solid 1px #000;
# }
# .subs-popup .info-box .field-title {
#     font-size: 16px;
#     font-weight: bold;
#     color: #000;
#     margin-bottom: 5px;
# }
# .subs-popup .info-box .field-link a {
#     color: #000;
#     text-decoration: underline;
# }
# </style></div>
# </div> </div><!-- #rjth-region-header -->
# </div>
# </div>
# </div>
# <!-- end #menu-top -->
# <div class="rj-container menu-main-container">
# <div id="menu-main">
# <div class="menu-weather">
# <a href="/weather" title="Weather Forecast">
# <span class="wdegrees">88°F</span>
# <img alt="weather icon" class="wicon" src="https://res.cloudinary.com/review-journal/image/upload/f_auto,q_auto,c_scale,w_40/rj-project/apple_weather/ClearDay.png"/>
# </a>
# </div>
# <div class="menu-top-menu-container"><ul class="nav navbar-nav" id="primary-menu"><li class="gtm_event_track event_info-Main_Nav_Click-News menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2514828" id="menu-item-2514828"><a href="https://www.reviewjournal.com/./news/">News</a></li>
# <li class="gtm_event_track event_info-Main_Nav_Click-Local menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2514830" id="menu-item-2514830"><a href="https://www.reviewjournal.com/./local/">Local</a></li>
# <li class="gtm_event_track event_info-Main_Nav_Click-Sports menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent menu-item-2514829" id="menu-item-2514829"><a href="https://www.reviewjournal.com/./sports/">Sports</a></li>
# <li class="gtm_event_track event_info-Main_Nav_Click-Business menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2514832" id="menu-item-2514832"><a href="https://www.reviewjournal.com/./business/">Business</a></li>
# <li class="gtm_event_track event_info-Main_Nav_Click-Opinion menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2514833" id="menu-item-2514833"><a href="https://www.reviewjournal.com/./opinion/">Opinion</a></li>
# <li class="gtm_event_track event_info-Main_Nav_Click-Crime menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2514835" id="menu-item-2514835"><a href="https://www.reviewjournal.com/./crime/">Crime</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2654339" id="menu-item-2654339"><a href="https://www.reviewjournal.com/./livewell/">Live Well</a></li>
# <li class="gtm_event_track event_info-Main_Nav_Click-Entertainment menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2514831" id="menu-item-2514831"><a href="https://www.reviewjournal.com/./entertainment/">Entertainment</a></li>
# <li class="gtm_event_track event_info-Main_Nav_Click-Investigations menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2514839" id="menu-item-2514839"><a href="https://www.reviewjournal.com/./investigations/">Investigations</a></li>
# <li class="gtm_event_track event_info-Main_Nav_Click-Obits menu-item menu-item-type-custom menu-item-object-custom menu-item-1666637" id="menu-item-1666637"><a href="https://obituaries.reviewjournal.com/" rel="noopener" target="_blank">Obits</a></li>
# </ul></div> <div class="menu-search">
# <div class="menu-search-helper">
# <form action="https://www.reviewjournal.com/" class="search-form">
# <input class="search-text" name="s" placeholder="Enter your search term..." type="search"/>
# </form>
# <a class="search-icon" href="#" title="search icon">
# <i aria-hidden="true" class="fa fa-search"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- #menu-slide -->
# <div class="side-rail-nav" id="side-rail-nav">
# <a aria-label="close-button" href="#" id="close-side-rail-nav"></a>
# <div id="weather-widget">
# <div class="wdegrees">88°F</div>
# <img alt="weather icon" class="wicon" src="https://res.cloudinary.com/review-journal/image/upload/f_auto,q_auto,c_scale,w_40/rj-project/apple_weather/ClearDay.png"/>
# <span>Clear</span>
# <div class="wcity"><a href="/weather" title="Weather Forecast">Las Vegas, NV</a></div>
# </div>
# <form action="https://www.reviewjournal.com/" class="search-form">
# <input class="search-text" name="s" placeholder="search..." type="search"/>
# <a class="search-icon" href="#" title="search icon">
# <i aria-hidden="true" class="fa fa-search"></i>
# </a>
# </form>
# <ul class="rj-slide-nav" id="slide-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-865633" id="menu-item-865633"><a href="/">Home</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2571266" id="menu-item-2571266"><a href="https://espanol.reviewjournal.com/?utm_campaign=RJ_Cross_Traffic&amp;utm_source=Main_Nav_Link&amp;utm_medium=NavLink" target="_blank">RJESPAÑOL</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2257346" id="menu-item-2257346"><a href="https://www.reviewjournal.com/7at7/">7@7 video</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2632955" id="menu-item-2632955"><a href="https://www.reviewjournal.com/tag/lake-mead/">Lake Mead</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2632956" id="menu-item-2632956"><a href="https://www.reviewjournal.com/news/politics-and-government/nevada/2023-legislature/">2023 Legislature</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2733751" id="menu-item-2733751"><a href="https://www.reviewjournal.com/tag/what-are-they-hiding/">What Are They Hiding?</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-865634" id="menu-item-865634"><a href="https://www.reviewjournal.com/./news/">News</a>
# <div class="dropdown">
# <div class="h4"><a href="https://www.reviewjournal.com/./news/"><strong>News</strong> <span>Section</span></a></div>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-985517" id="menu-item-985517"><a href="https://www.reviewjournal.com/./local/education/">Education</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-985518" id="menu-item-985518"><a href="https://www.reviewjournal.com/./news/politics-and-government/">Politics and Government</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2715892" id="menu-item-2715892"><a href="https://www.reviewjournal.com/./news/politics-and-government/nevada/2023-legislature/">2023 Legislature</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2768318" id="menu-item-2768318"><a href="https://www.reviewjournal.com/tag/2024-election/">2024 Election</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-985541" id="menu-item-985541"><a href="https://www.reviewjournal.com/./news/politics-and-government/nevada/">Nevada</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-985539" id="menu-item-985539"><a href="https://www.reviewjournal.com/./news/politics-and-government/clark-county/">Clark County</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-985540" id="menu-item-985540"><a href="https://www.reviewjournal.com/./news/politics-and-government/las-vegas/">Las Vegas</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-865636" id="menu-item-865636"><a href="https://www.reviewjournal.com/./news/nation-and-world/">Nation and World</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-985520" id="menu-item-985520"><a href="https://www.reviewjournal.com/./news/science-and-technology/">Science and Technology</a></li>
# <li class="hide menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-985521" id="menu-item-985521"><a href="https://www.reviewjournal.com/./news/special-features/">Special Features</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1649702" id="menu-item-1649702"><a href="https://www.reviewjournal.com/./news/despair/">State of Despair</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1934896" id="menu-item-1934896"><a href="https://www.reviewjournal.com/tag/alpine-motel-fire/">Alpine Motel fire</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1847113" id="menu-item-1847113"><a href="https://www.reviewjournal.com/tag/storm-area-51/">Storm Area 51</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-865637" id="menu-item-865637"><a href="https://www.reviewjournal.com/./news/news-columns/">News Columns</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-865640" id="menu-item-865640"><a href="https://www.reviewjournal.com/./news/news-columns/road-warrior/">Road Warrior</a></li>
# </ul>
# </li>
# ...
#     bottom: 0;
#     left: 0;
#     padding: 10px;
#     width: 100%;
#     font-size: 13px;
#     font-family: "Merriweather", serif;
#     color:#fff;
#     background-color: rgba(0, 0, 0, 0.7);;
#     border: solid 1px #000;
#     line-height: 1.3;
#     display: none;
# }
# .accept-cookie .field-btn {
#     display: inline-block;
#     padding: 5px 10px;
#     background-color: #d82121;
#     color: #fff;
#     font-weight: bold;
#     font-size: 14px;
#     margin-top: 10px;
#     cursor: pointer;
# }
# .accept-cookie .x-btn {
#   float: right;
#   display: inline-block;
#   margin: 0 0 5px 8px;
#   padding: 1px 5px 3px 5px;
#   font-size: 16px;
#   font-weight: bold;
#   color: #fff;
#   background-color: #d82121;
#   cursor: pointer;
# }
# </style>
# <script>
# (function ($) {
#     $(document).ready(function (e) {
#         if (/bot|lighthouse/i.test(navigator.userAgent)) {
#             return;
#         }
#         if (window.localStorage) {
#             check_storage();
#         } else {
#             check_cookie();
#         }
#
#         function check_storage() {
#             var is_accept_cookie = getCookie('is_accept_cookie');
#             //console.log('rj_cookie:'+is_accept_cookie);
#             if (is_accept_cookie == '1') {
#                 return;
#             }
#
#             current_date = new Date().getTime();
#             current_date = current_date / (1000); //24*60*60*
#             current_date = parseInt(current_date);
#
#             $('.accept-cookie .field-btn').click(function() {
#                 window.localStorage.setItem('rj_cookie_date', current_date);
#                 window.localStorage.setItem('rj_cookie_diff', (365*24*60*60));
#                 $('.accept-cookie').hide();
#             });
#
#             $('.accept-cookie .x-btn').click(function() {
#                 window.localStorage.setItem('rj_cookie_date', current_date);
#                 window.localStorage.setItem('rj_cookie_diff', (1*24*60*60));
#                 $('.accept-cookie').hide();
#             });
#
#             var rj_cookie_date = window.localStorage.getItem('rj_cookie_date');
#             rj_cookie_date = parseInt(rj_cookie_date);
#             if (!Number.isInteger(rj_cookie_date)) {
#                 rj_cookie_date = 0;
#             }
#
#             var rj_cookie_diff = window.localStorage.getItem('rj_cookie_diff');
#             rj_cookie_diff = parseInt(rj_cookie_diff);
#             //console.log('rj_cookie_diff:'+rj_cookie_diff);
#             if (rj_cookie_diff != (365*24*60*60)) {
#                 rj_cookie_diff = (1*24*60*60);
#             }
#
#             var date_diff = current_date - rj_cookie_date;
#             //console.log('rj_cookie_diff:'+ rj_cookie_diff);
#             var dd = date_diff/86400;
#             dd = dd.toFixed(2);
#             //console.log('rj_cookie_date:'+dd );
#             if (dd > 5) {
#                 dd = 5;
#             }
#             //$('.powered-by').append(dd);
#             //$('.powered-by').append('<div>'+date_diff+'|'+rj_cookie_diff+'</div>');
#
#             if (date_diff >= rj_cookie_diff) {
#                 $('.accept-cookie').show();
#             }
#         }
#
#         function check_cookie() {
#             $('.accept-cookie .field-btn').bind('click', accept_cookie);
#             $('.accept-cookie .x-btn').bind('click', x_btn_clicked);
#
#             var is_accept_cookie = getCookie('is_accept_cookie');
#             if (is_accept_cookie != '1' && is_accept_cookie != '0') {
#                 $('.accept-cookie').show();
#             }
#         }
#
#         function x_btn_clicked() {
#             setCookie('is_accept_cookie', '0', 1); //1year = 365, 10 mins = 0.007
#             $('.accept-cookie').hide();
#         }
#
#         function accept_cookie() {
#             setCookie('is_accept_cookie', '1', 365); //1year = 365, 10 mins = 0.007
#             $('.accept-cookie').hide();
#         }
#         function setCookie(cname, cvalue, exdays) {
#             var d = new Date();
#             d.setTime(d.getTime() + (exdays * 24 * 60 * 60 * 1000));
#             var expires = 'expires='+d.toUTCString();
#             document.cookie = cname + '=' + cvalue + ';' + expires + ';path=/';
#         }
#         function getCookie(a) {
#             var b = document.cookie.match('(^|[^;]+)\\s*' + a + '\\s*=\\s*([^;]+)');
#             return b ? b.pop() : '';
#         }
#     });
# })(jQuery);
# </script></div>
# </div> </div>
# </div>
# </footer><!-- #rj-footer -->
# <div id="jp-carousel-loading-overlay">
# <div id="jp-carousel-loading-wrapper">
# <span id="jp-carousel-library-loading"> </span>
# </div>
# </div>
# <div class="jp-carousel-overlay" style="display: none;">
# <div class="jp-carousel-container">
# <!-- The Carousel Swiper -->
# <div class="jp-carousel-wrap swiper-container jp-carousel-swiper-container jp-carousel-transitions" itemscope="" itemtype="https://schema.org/ImageGallery">
# <div class="jp-carousel swiper-wrapper"></div>
# <div class="jp-swiper-button-prev swiper-button-prev">
# <svg fill="none" height="24" viewbox="0 0 25 24" width="25" xmlns="http://www.w3.org/2000/svg">
# <mask height="12" id="maskPrev" mask-type="alpha" maskunits="userSpaceOnUse" width="9" x="8" y="6">
# <path d="M16.2072 16.59L11.6496 12L16.2072 7.41L14.8041 6L8.8335 12L14.8041 18L16.2072 16.59Z" fill="white"></path>
# </mask>
# <g mask="url(#maskPrev)">
# <rect fill="#FFFFFF" height="24" width="23.8823" x="0.579102"></rect>
# </g>
# </svg>
# </div>
# <div class="jp-swiper-button-next swiper-button-next">
# <svg fill="none" height="24" viewbox="0 0 25 24" width="25" xmlns="http://www.w3.org/2000/svg">
# <mask height="12" id="maskNext" mask-type="alpha" maskunits="userSpaceOnUse" width="8" x="8" y="6">
# <path d="M8.59814 16.59L13.1557 12L8.59814 7.41L10.0012 6L15.9718 12L10.0012 18L8.59814 16.59Z" fill="white"></path>
# </mask>
# <g mask="url(#maskNext)">
# <rect fill="#FFFFFF" height="24" width="23.8822" x="0.34375"></rect>
# </g>
# </svg>
# </div>
# </div>
# <!-- The main close buton -->
# <div class="jp-carousel-close-hint">
# <svg fill="none" height="24" viewbox="0 0 25 24" width="25" xmlns="http://www.w3.org/2000/svg">
# <mask height="14" id="maskClose" mask-type="alpha" maskunits="userSpaceOnUse" width="15" x="5" y="5">
# <path d="M19.3166 6.41L17.9135 5L12.3509 10.59L6.78834 5L5.38525 6.41L10.9478 12L5.38525 17.59L6.78834 19L12.3509 13.41L17.9135 19L19.3166 17.59L13.754 12L19.3166 6.41Z" fill="white"></path>
# </mask>
# <g mask="url(#maskClose)">
# <rect fill="#FFFFFF" height="24" width="23.8823" x="0.409668"></rect>
# </g>
# </svg>
# </div>
# <!-- Image info, comments and meta -->
# <div class="jp-carousel-info">
# <div class="jp-carousel-info-footer">
# <div class="jp-carousel-pagination-container">
# <div class="jp-swiper-pagination swiper-pagination"></div>
# <div class="jp-carousel-pagination"></div>
# </div>
# <div class="jp-carousel-photo-title-container">
# <h2 class="jp-carousel-photo-caption"></h2>
# </div>
# <div class="jp-carousel-photo-icons-container">
# <a aria-label="Toggle photo metadata visibility" class="jp-carousel-icon-btn jp-carousel-icon-info" href="#">
# <span class="jp-carousel-icon">
# <svg fill="none" height="24" viewbox="0 0 25 24" width="25" xmlns="http://www.w3.org/2000/svg">
# <mask height="20" id="maskInfo" mask-type="alpha" maskunits="userSpaceOnUse" width="21" x="2" y="2">
# <path clip-rule="evenodd" d="M12.7537 2C7.26076 2 2.80273 6.48 2.80273 12C2.80273 17.52 7.26076 22 12.7537 22C18.2466 22 22.7046 17.52 22.7046 12C22.7046 6.48 18.2466 2 12.7537 2ZM11.7586 7V9H13.7488V7H11.7586ZM11.7586 11V17H13.7488V11H11.7586ZM4.79292 12C4.79292 16.41 8.36531 20 12.7537 20C17.142 20 20.7144 16.41 20.7144 12C20.7144 7.59 17.142 4 12.7537 4C8.36531 4 4.79292 7.59 4.79292 12Z" fill="white" fill-rule="evenodd"></path>
# </mask>
# <g mask="url(#maskInfo)">
# <rect fill="#FFFFFF" height="24" width="23.8823" x="0.8125"></rect>
# </g>
# </svg>
# </span>
# </a>
# </div>
# </div>
# <div class="jp-carousel-info-extra">
# <div class="jp-carousel-info-content-wrapper">
# <div class="jp-carousel-photo-title-container">
# <h2 class="jp-carousel-photo-title"></h2>
# </div>
# <div class="jp-carousel-comments-wrapper">
# </div>
# <div class="jp-carousel-image-meta">
# <div class="jp-carousel-title-and-caption">
# <div class="jp-carousel-photo-info">
# <h3 class="jp-carousel-caption" itemprop="caption description"></h3>
# </div>
# <div class="jp-carousel-photo-description"></div>
# </div>
# <ul class="jp-carousel-image-exif" style="display: none;"></ul>
# <a class="jp-carousel-image-download" style="display: none;" target="_blank">
# <svg fill="none" height="24" viewbox="0 0 25 24" width="25" xmlns="http://www.w3.org/2000/svg">
# <mask height="18" id="mask0" mask-type="alpha" maskunits="userSpaceOnUse" width="19" x="3" y="3">
# <path clip-rule="evenodd" d="M5.84615 5V19H19.7775V12H21.7677V19C21.7677 20.1 20.8721 21 19.7775 21H5.84615C4.74159 21 3.85596 20.1 3.85596 19V5C3.85596 3.9 4.74159 3 5.84615 3H12.8118V5H5.84615ZM14.802 5V3H21.7677V10H19.7775V6.41L9.99569 16.24L8.59261 14.83L18.3744 5H14.802Z" fill="white" fill-rule="evenodd"></path>
# </mask>
# <g mask="url(#mask0)">
# <rect fill="#FFFFFF" height="24" width="23.8823" x="0.870605"></rect>
# </g>
# </svg>
# <span class="jp-carousel-download-text"></span>
# </a>
# <div class="jp-carousel-image-map" style="display: none;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <link href="https://www.reviewjournal.com/_static/??-eJydzMkNgCAQQNGGhBGJ28FYi8LEoGxhmNi+8WADXv9PHtxZmBQrxgqBRfZ8uEhwYs2buYTqZAchWfZIYLaSmNAD3S5jETtH61Eaogb+MN/9wiutYVHDNM5a9+38AOK7OIs=" id="all-css-0" media="all" rel="stylesheet" type="text/css">
# <script src="https://www.reviewjournal.com/_static/??/wp-includes/js/jquery/ui/core.min.js,/wp-includes/js/jquery/ui/tabs.min.js?m=1687285577j" type="text/javascript"></script><script defer="" id="jetpack-stats-js" src="https://stats.wp.com/e-202326.js"></script>
# <script id="jetpack-stats-js-after">
# _stq = window._stq || [];
# _stq.push([ "view", {v:'ext',blog:'124460806',post:'2785339',tz:'-7',srv:'www.reviewjournal.com',hp:'vip',j:'1:12.2.1'} ]);
# _stq.push([ "clickTrackerInit", "124460806", "2785339" ]);
# </script>
# <script id="jetpack-carousel-js-extra">
# var jetpackSwiperLibraryPath = {"url":"https:\/\/www.reviewjournal.com\/wp-content\/mu-plugins\/jetpack-12.2\/_inc\/build\/carousel\/swiper-bundle.min.js"};
# var jetpackCarouselStrings = {"widths":[370,700,1000,1200,1400,2000],"is_logged_in":"","lang":"en","ajaxurl":"https:\/\/www.reviewjournal.com\/wp-admin\/admin-ajax.php","nonce":"ba64cb3957","display_exif":"0","display_comments":"0","single_image_gallery":"1","single_image_gallery_media_file":"","background_color":"black","comment":"Comment","post_comment":"Post Comment","write_comment":"Write a Comment...","loading_comments":"Loading Comments...","download_original":"View full size <span class=\"photo-size\">{0}<span class=\"photo-size-times\">\u00d7<\/span>{1}<\/span>","no_comment_text":"Please be sure to submit some text with your comment.","no_comment_email":"Please provide an email address to comment.","no_comment_author":"Please provide your name to comment.","comment_post_error":"Sorry, but there was an error posting your comment. Please try again later.","comment_approved":"Your comment was approved.","comment_unapproved":"Your comment is in moderation.","camera":"Camera","aperture":"Aperture","shutter_speed":"Shutter Speed","focal_length":"Focal Length","copyright":"Copyright","comment_registration":"0","require_name_email":"0","login_url":"https:\/\/www.reviewjournal.com\/wp-login.php?redirect_to=https%3A%2F%2Fwww.reviewjournal.com%2Fsports%2Fbetting%2Fcollege-football-regular-season-win-totals-full-list-of-133-teams-2785339%2F","blog_id":"1","meta_data":["camera","aperture","shutter_speed","focal_length","copyright"]};
# </script>
# <script src="https://www.reviewjournal.com/wp-content/mu-plugins/jetpack-12.2/_inc/build/carousel/jetpack-carousel.min.js?m=1687933508g" type="text/javascript"></script>
# <script>
#                 var parselyPreload = {eventQueue: [], loaded: false};
#
#                 function fireParselyEvent(event) {
#                     if (parselyPreload.loaded) {
#                         PARSELY.beacon.trackPageView(event);
#                     } else {
#                         parselyPreload.eventQueue.push(event);
#                     }
#                 }
#
#                 // when Parse.ly is done loading, flush the queue
#                 window.PARSELY = {
#                     onload: function () {
#                         console.log("Parse.ly code has loaded!");
#                         parselyPreload.loaded = true;
#                         for (var i = 0; i < parselyPreload.eventQueue.length; i++) {
#                             PARSELY.beacon.trackPageView(parselyPreload.eventQueue[i]);
#                         }
#                     }
#                 };
#
#
#                 PARSELY.autotrack = false;
#                 PARSELY.onReady = function () {
#                     console.log("Parse.ly code is ready!");
#                     getSubscriberInfo();
#                 };
#
#                 window.rjConnext = {
#                     init: false,
#                     done: false,
#                     viewed: false,
#                     getUserState: function() {
#                         if (window.Connext && window.Connext.Storage && window.Connext.Storage.GetUserState) {
#                             return window.Connext.Storage.GetUserState();
#                         }
#                         return null;
#                     },
#                     isReady: function() {
#                         return window.rjConnext.done && !window.rjConnext.viewed;
#                     },
#                     onFinish: function(e) {
#                         window.rjConnext.done = true;
#                     },
#                     complete: function() {
#                         window.rjConnext.init = true;
#                         window.rjConnext.done = true;
#                         window.rjConnext.viewed = true;
#                     }
#                 };
#
#                 document.addEventListener("onFinish", function(e) {
#                     console.log("Parse.ly EventListener: onFinish.", e);
#                     window.rjConnext.onFinish(e);
#                 });
#
#                 function getSubscriberInfo() {
#                     if (window.rjConnext.init) {
#                         return;
#                     }
#                     window.rjConnext.init = true;
#                     if (window.rjConnext.isReady()) {
#                         parselyTrackAudienceSegments(window.rjConnext.getUserState());
#                     } else {
#                         // wait for Connext to load (no more than 10 seconds)
#                         var try_max = 20, try_count = 0;
#                         var try_timer = setInterval(function () {
#                             try_count++;
#                             if (try_count < try_max) {
#                                 if (window.rjConnext.isReady()) {
#                                     clearInterval(try_timer);
#                                     parselyTrackAudienceSegments(window.rjConnext.getUserState());
#                                 }
#                             } else {
#                                 clearInterval(try_timer);
#                                 parselyTrackAudienceSegments(null);
#                             }
#                         }, 500);
#                     }
#                 }
#
#                 function parselyTrackAudienceSegments(subscription) {
#                     window.rjConnext.complete();
#                     console.log('Parse.ly Track Audience', subscription);
#                     PARSELY.updateDefaults({
#                         data: {
#                             plan: subscription
#                         }
#                     });
#                     PARSELY.beacon.trackPageView();
#                 }
# 							</script>
# <!-- START Parse.ly Include: Standard -->
# <script async="true" data-cfasync="false" data-parsely-site="lasvegasreviewjournal.com" id="parsely-cfg" src="https://cdn.parsely.com/keys/lasvegasreviewjournal.com/p.js"></script>
# <!-- END Parse.ly Include: Standard -->
# </link></body>
# </html>

# %%
import re

# Trimming the beginning and ending of our dataset because we know it's not important
body = soup.findAll('p')[2:-12]

# Converting our list to a string so we can use "findall and regular expressions
data = str(body)
team_names = re.findall(r'<p>([A-Z][\w\s]+)', data)
win_totals = re.findall(r'; ([\d½]+)', data)
odds = re.findall(r'\((u-\d+|\bo-\d+)\)', data)

# Putting this info into a dataframe
df_133 = pd.DataFrame({
    'Team': team_names,
    'Win Total': win_totals,
#    'Odds': odds
})

df_133.head(25)
# Out:
#               Team Win Total
# 0          Georgia        11
# 1         Michigan       10½
# 2       Ohio State       10½
# 3              USC        10
# 4          Clemson        10
# 5          Alabama        10
# 6    Florida State        9½
# 7            Texas        9½
# 8       Penn State        9½
# 9              LSU        9½
# 10        Oklahoma        9½
# 11          Oregon        9½
# 12      Washington        9½
# 13          Tulane         9
# 14       Tennessee         9
# 15         Liberty        8½
# 16          Toledo        8½
# 17            Troy        8½
# 18       Wisconsin        8½
# 19      Notre Dame        8½
# 20            UCLA        8½
# 21       Air Force        8½
# 22  North Carolina        8½
# 23     Boise State        8½
# 24            Utah        8½

# %%
# Ensure we have 133 teams

df_133.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Team       133 non-null    object
#  1   Win Total  133 non-null    object
# dtypes: object(2)
# memory usage: 2.2+ KB

# %%
# Perform left merge and indicate the source of each row
merged = pd.merge(df_133, df, on='Team', how='left', indicator=True, sort = True)

# Filter rows that exist in the first dataset but not in the second dataset
rows_only_in_df_133 = merged[merged['_merge'] == 'left_only']

print("this is the amount of differenec : ", len(rows_only_in_df_133),rows_only_in_df_133)
# Out:
# this is the amount of differenec :  24                        Team Win Total Over Under  Over_Value  Final_Converted  \
# 16            Brigham Young        5½  NaN   NaN         NaN              NaN
# 17                  Buffalo        6½  NaN   NaN         NaN              NaN
# 19          Central Florida         7  NaN   NaN         NaN              NaN
# 27              Connecticut        4½  NaN   NaN         NaN              NaN
# 32         Florida Atlantic        7½  NaN   NaN         NaN              NaN
# 33    Florida International        3½  NaN   NaN         NaN              NaN
# 40                   Hawaii        3½  NaN   NaN         NaN              NaN
# 46            Jackson State        5½  NaN   NaN         NaN              NaN
# 59                  Memphis        7½  NaN   NaN         NaN              NaN
# 60                   Miami         7½  NaN   NaN         NaN              NaN
# 61                   Miami         6½  NaN   NaN         NaN              NaN
# 64   Middle Tennessee State        6½  NaN   NaN         NaN              NaN
# 66              Mississippi        7½  NaN   NaN         NaN              NaN
# 72         New Mexico State        5½  NaN   NaN         NaN              NaN
# 90                  Rutgers         4  NaN   NaN         NaN              NaN
# 91        Sam Houston State        3½  NaN   NaN         NaN              NaN
# 97       Southern Methodist        8½  NaN   NaN         NaN              NaN
# 98     Southern Mississippi         5  NaN   NaN         NaN              NaN
# 106                 Texas A        8½  NaN   NaN         NaN              NaN
# 107         Texas Christian        7½  NaN   NaN         NaN              NaN
# 110                  Toledo        8½  NaN   NaN         NaN              NaN
# 115            UL Lafayette        7½  NaN   NaN         NaN              NaN
# 116               UL Monroe         3  NaN   NaN         NaN              NaN
# 118                     UNR         4  NaN   NaN         NaN              NaN
#
#         _merge
# 16   left_only
# 17   left_only
# 19   left_only
# 27   left_only
# 32   left_only
# 33   left_only
# 40   left_only
# 46   left_only
# 59   left_only
# 60   left_only
# 61   left_only
# 64   left_only
# 66   left_only
# 72   left_only
# 90   left_only
# 91   left_only
# 97   left_only
# 98   left_only
# 106  left_only
# 107  left_only
# 110  left_only
# 115  left_only
# 116  left_only
# 118  left_only

# %% [markdown]
# So there's 18 rows here we must calculate that are redundant or not. Another issue I thought of is different tables using different team names or abbreviations. We will not tackle a suitable solution for this project, but we will use the merge similar to above to list all the teams in our original DataFrame that doesn't show up, and then manually check those lists to find some missing links.

# %%
# Perform left merge and indicate the source of each row
merged = pd.merge(df, df_133, on='Team', how='left', indicator=True)

# Filter rows that exist in the first dataset but not in the second dataset
rows_only_in_df = merged[merged['_merge'] == 'left_only']

print("this is the amount of difference : ", len(rows_only_in_df), rows_only_in_df)
# Out:
# this is the amount of difference :  21                             Team      Over     Under  Over_Value  \
# 16                           BYU  5.5 −120  5.5 +100         5.5
# 28                           FIU  2.5 −145  2.5 +120         2.5
# 36             Hawaii (13 Games)  3.5 +115  3.5 −140         3.5
# 42            Jacksonville State  5.5 −110  5.5 −115         5.5
# 50           Louisiana-Lafayette  5.5 −110  5.5 −115         5.5
# 56                      Miami FL  7.5 +120  7.5 −140         7.5
# 57                      Miami OH  6.5 −110  6.5 −115         6.5
# 60              Middle Tennessee  6.5 −125  6.5 +100         6.5
# 66                        Nevada    3 −160    3 +135         3.0
# 68   New Mexico State (13 Games)    5 −120    5 −105         5.0
# 80                      Ole Miss  6.5 +100  6.5 −120         6.5
# 87                   Sam Houston    4 −125    4 +100         4.0
# 90                           SMU    8 −110    8 −115         8.0
# 94                 Southern Miss    5 +100    5 −125         5.0
# 97                           TCU  7.5 −125  7.5 +105         7.5
# 103                    Texas A&M  7.5 −150  7.5 +130         7.5
# 109                          UAB    5 −130    5 +105         5.0
# 110                          UCF  6.5 −150  6.5 +130         6.5
# 112                        UConn  5.5 +105  5.5 −130         5.5
# 113                          ULM  3.5 +125  3.5 −150         3.5
# 118                         UTEP  5.5 +100  5.5 −125         5.5
#
#      Final_Converted Win Total     _merge
# 16          5.750000       NaN  left_only
# 28          2.729592       NaN  left_only
# 36          3.377907       NaN  left_only
# 42          5.630952       NaN  left_only
# 50          5.630952       NaN  left_only
# 56          7.159091       NaN  left_only
# 57          6.654762       NaN  left_only
# 60          6.861111       NaN  left_only
# 66          3.346154       NaN  left_only
# 68          5.227273       NaN  left_only
# 80          6.500000       NaN  left_only
# 87          4.222222       NaN  left_only
# 90          8.190476       NaN  left_only
# 94          5.000000       NaN  left_only
# 97          7.916667       NaN  left_only
# 103         8.250000       NaN  left_only
# 109         5.326087       NaN  left_only
# 110         7.150000       NaN  left_only
# 112         5.432927       NaN  left_only
# 113         3.305556       NaN  left_only
# 118         5.500000       NaN  left_only

# %% [markdown]
# The teams our dataset is missing in alphabetical order are Buffalo, FAU (go owls), Memphis, Toledo, and Rutgers. I can't seem to find the last missing link! If someone does find it please let me know!
#
# I kept this part in to demonstrate that even though these tasks are automated by very powerful machines, if one doesn't perform Quality Assurance testing they could get themselves in trouble for ommiting data. Not only that, but the process to find the missing data or issue could be painstaking and tedious, as we had to manuelly check the differences between the 2 separate datasets above. Sometimes the code writes itself, other times, it requires attention to detail but all of it's necessary to try and find some truth in the matter.
#
# For the sake of this project, I will take the one missing link for the 132 we were able to process and compute.
#
# Thanks again for reading!
